# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('game_data.csv')
df.drop('Unnamed: 0', axis = 'columns', inplace=True)
df
# Out:
#       rated   variant      speed       perf                         createdAt  \
# 0      True  standard     bullet     bullet  2022-08-30 02:47:26.190000+00:00
# 1      True  standard     bullet     bullet  2022-08-30 02:46:15.055000+00:00
# 2      True  standard     bullet     bullet  2022-08-30 02:28:55.840000+00:00
# 3      True  standard      blitz      blitz  2022-08-30 02:24:49.912000+00:00
# 4      True  standard      blitz      blitz  2022-08-29 23:14:46.983000+00:00
# ...     ...       ...        ...        ...                               ...
# 1204   True  standard      rapid      rapid  2019-04-15 22:12:18.221000+00:00
# 1205   True  standard      blitz      blitz  2019-04-13 20:54:06.845000+00:00
# 1206   True  standard      rapid      rapid  2019-04-13 20:43:08.889000+00:00
# 1207   True  standard      rapid      rapid  2019-04-12 02:55:21.683000+00:00
# 1208   True  standard  classical  classical  2019-04-09 12:29:18.450000+00:00
#
#          status winner                                              moves  \
# 0     outoftime  black  d4 Nf6 c4 e6 g3 d5 Bg2 Bb4+ Bd2 Bxd2+ Qxd2 Nc6...
# 1     outoftime  black                                             Nc3 e5
# 2          mate  black  e4 c6 Bc4 d5 exd5 cxd5 Bb3 Nf6 Qf3 Nc6 d4 Bg4 ...
# 3          mate  white  e4 c5 Nf3 e6 d4 cxd4 Nxd4 Nc6 Nc3 Nf6 Be3 d5 e...
# 4          mate  black  d4 Nf6 c4 e5 Nc3 b6 Bg5 Be7 e3 exd4 Qxd4 Nc6 Q...
# ...         ...    ...                                                ...
# 1204    timeout  white  e4 c5 Bc4 e6 e5 d5 Bb5+ Bd7 Bxd7+ Nxd7 c3 Nxe5...
# 1205     resign  black  c4 Nf6 Nc3 g6 g3 Bg7 Bg2 O-O e4 Re8 d3 d6 Nf3 ...
# 1206       mate  white  e4 c6 d4 d5 e5 e6 Nf3 Ne7 Nc3 Nd7 Bd3 f6 O-O N...
# 1207       mate  white  e4 c6 Bc4 d5 exd5 cxd5 Bb3 Bf5 d4 e6 h3 Nc6 c3...
# 1208       draw    NaN  c4 e5 Nc3 Bc5 e3 Nf6 Nge2 Nc6 g3 b6 Bg2 Bb7 d4...
#
#                                                   clock  ECO  \
# 0      {'initial': 60, 'increment': 0, 'totalTime': 60}  E01
# 1      {'initial': 60, 'increment': 0, 'totalTime': 60}  A00
# 2     {'initial': 120, 'increment': 1, 'totalTime': ...  B10
# 3     {'initial': 180, 'increment': 2, 'totalTime': ...  B40
# 4     {'initial': 300, 'increment': 3, 'totalTime': ...  A51
# ...                                                 ...  ...
# 1204  {'initial': 600, 'increment': 0, 'totalTime': ...  B20
# 1205  {'initial': 180, 'increment': 0, 'totalTime': ...  A16
# 1206  {'initial': 600, 'increment': 0, 'totalTime': ...  B12
# 1207  {'initial': 600, 'increment': 0, 'totalTime': ...  B10
# 1208  {'initial': 900, 'increment': 15, 'totalTime':...  A21
#
#                                            opening_name          white_player  \
# 0                               Catalan Opening: Closed          'chestroyer'
# 1                Van Geet Opening: Reversed Nimzowitsch       'tanishkpanara'
# 2                   Caro-Kann Defense: Hillbilly Attack          'chestroyer'
# 3              Sicilian Defense: Four Knights Variation  'gaspar_deepblueyev'
# 4                      Indian Defense: Budapest Defense          'chestroyer'
# ...                                                 ...                   ...
# 1204                   Sicilian Defense: Bowdler Attack         't-2wadbee-t'
# 1205  English Opening: Anglo-Indian Defense, Queen's...          'chestroyer'
# 1206               Caro-Kann Defense: Advance Variation           'emerson88'
# 1207                Caro-Kann Defense: Hillbilly Attack               'cyote'
# 1208  English Opening: King's English Variation, Rev...          'chestroyer'
#
#      rating     black_player rating.1
# 0      1075   'elusivedemon'     1157
# 1      932,     'chestroyer'     1070
# 2      1079  'katfishngrits'     1065
# 3      1576     'chestroyer'     1463
# 4      1470     'kamikaze27'     1480
# ...     ...              ...      ...
# 1204   1241     'chestroyer'     1241
# 1205   1500       'dancab07'     1506
# 1206   1386     'chestroyer'     1346
# 1207   1546     'chestroyer'     1500
# 1208   1500       'mass1962'     1510
#
# [1209 rows x 15 columns]

# %%
df.describe()
# Out:
#        rated   variant  speed   perf                         createdAt status  \
# count   1209      1209   1209   1209                              1209   1209
# unique     2         2      5      5                              1209      6
# top     True  standard  blitz  blitz  2022-08-30 02:47:26.190000+00:00   mate
# freq    1200      1203    554    554                                 1    495
#
#        winner                                              moves  \
# count    1164                                               1209
# unique      2                                               1209
# top     white  d4 Nf6 c4 e6 g3 d5 Bg2 Bb4+ Bd2 Bxd2+ Qxd2 Nc6...
# freq      634                                                  1
#
#                                                     clock   ECO  \
# count                                                1207  1209
# unique                                                 15   148
# top     {'initial': 300, 'increment': 0, 'totalTime': ...   B20
# freq                                                  318    75
#
#             opening_name  white_player rating  black_player rating.1
# count               1209          1209   1209          1209     1209
# unique               326           600    603           595      590
# top     Sicilian Defense  'chestroyer'   1500  'chestroyer'     1051
# freq                  56           603     15           606        8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rated         1209 non-null   bool
#  1   variant       1209 non-null   object
#  2   speed         1209 non-null   object
#  3   perf          1209 non-null   object
#  4   createdAt     1209 non-null   object
#  5   status        1209 non-null   object
#  6   winner        1164 non-null   object
#  7   moves         1209 non-null   object
#  8   clock         1207 non-null   object
#  9   ECO           1209 non-null   object
#  10  opening_name  1209 non-null   object
#  11  white_player  1209 non-null   object
#  12  rating        1209 non-null   object
#  13  black_player  1209 non-null   object
#  14  rating.1      1209 non-null   object
# dtypes: bool(1), object(14)
# memory usage: 133.5+ KB

# %%
player_name = "'chestroyer'"

# %%
df.columns
columns_of_interest = ['rated', 'speed', 'status', 'winner', 'ECO', 'opening_name']
for column in columns_of_interest:
    print('-'*120)
    print(f'{column} analysis:\n{df[column].value_counts()}')
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# rated analysis:
# True     1200
# False       9
# Name: rated, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# speed analysis:
# blitz             554
# classical         321
# rapid             205
# bullet            127
# correspondence      2
# Name: speed, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# status analysis:
# mate         495
# resign       368
# outoftime    260
# timeout       42
# draw          24
# stalemate     20
# Name: status, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# winner analysis:
# white    634
# black    530
# Name: winner, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# ECO analysis:
# B20    75
# C00    69
# A45    59
# B50    55
# A40    48
#        ..
# B86     1
# C26     1
# A52     1
# D43     1
# C43     1
# Name: ECO, Length: 148, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# opening_name analysis:
# Sicilian Defense                                 56
# Indian Defense                                   46
# Sicilian Defense: Bowdler Attack                 33
# Caro-Kann Defense                                31
# Sicilian Defense: Modern Variations              28
#                                                  ..
# Ruy Lopez: Bird Variation                         1
# King's Pawn Game: Busch-Gass Gambit               1
# Sicilian Defense: Hyperaccelerated Fianchetto     1
# Scandinavian Defense: Blackburne Gambit           1
# Zukertort Opening: Ross Gambit                    1
# Name: opening_name, Length: 326, dtype: int64

# %%
for column in columns_of_interest[0:4]:
    fig, ax = plt.subplots(figsize=(10, 8))
    ax = sns.barplot(x= df[column].value_counts().index, y=df[column].value_counts().values, palette='YlGnBu', ax=ax)
    plt.title(f'{column} Barplot')

# %% [markdown]
# # Playing as White

# %%
playing_white = df.loc[df['white_player'] == player_name, :]
playing_white
# Out:
#       rated   variant      speed       perf                         createdAt  \
# 0      True  standard     bullet     bullet  2022-08-30 02:47:26.190000+00:00
# 2      True  standard     bullet     bullet  2022-08-30 02:28:55.840000+00:00
# 4      True  standard      blitz      blitz  2022-08-29 23:14:46.983000+00:00
# 6      True  standard      blitz      blitz  2022-08-28 17:31:49.316000+00:00
# 9      True  standard      blitz      blitz  2022-08-27 18:28:05.559000+00:00
# ...     ...       ...        ...        ...                               ...
# 1198   True  standard     bullet     bullet  2019-04-24 22:38:23.732000+00:00
# 1201   True  standard  classical  classical  2019-04-24 13:23:49.627000+00:00
# 1203   True  standard      rapid      rapid  2019-04-16 14:24:02.081000+00:00
# 1205   True  standard      blitz      blitz  2019-04-13 20:54:06.845000+00:00
# 1208   True  standard  classical  classical  2019-04-09 12:29:18.450000+00:00
#
#          status winner                                              moves  \
# 0     outoftime  black  d4 Nf6 c4 e6 g3 d5 Bg2 Bb4+ Bd2 Bxd2+ Qxd2 Nc6...
# 2          mate  black  e4 c6 Bc4 d5 exd5 cxd5 Bb3 Nf6 Qf3 Nc6 d4 Bg4 ...
# 4          mate  black  d4 Nf6 c4 e5 Nc3 b6 Bg5 Be7 e3 exd4 Qxd4 Nc6 Q...
# 6     outoftime  white  e4 c5 c3 g6 Nf3 Bg7 d4 cxd4 cxd4 Nc6 Bb5 d6 Be...
# 9       timeout  white  d4 d5 c4 c6 Bf4 dxc4 Nc3 b5 a3 Bb7 e3 Nf6 h3 e...
# ...         ...    ...                                                ...
# 1198     resign  black  Nf3 Nf6 e4 g6 Bc4 Bg7 d4 O-O Bg5 d6 O-O b6 e5 ...
# 1201     resign  black  Nf3 c5 e4 d6 Bb5+ Bd7 a4 Nc6 O-O g6 d4 cxd4 Nx...
# 1203    timeout  white  Nf3 e5 d3 d6 e4 Nf6 Nc3 Be7 h3 O-O Bg5 a5 d4 e...
# 1205     resign  black  c4 Nf6 Nc3 g6 g3 Bg7 Bg2 O-O e4 Re8 d3 d6 Nf3 ...
# 1208       draw    NaN  c4 e5 Nc3 Bc5 e3 Nf6 Nge2 Nc6 g3 b6 Bg2 Bb7 d4...
#
#                                                   clock  ECO  \
# 0      {'initial': 60, 'increment': 0, 'totalTime': 60}  E01
# 2     {'initial': 120, 'increment': 1, 'totalTime': ...  B10
# 4     {'initial': 300, 'increment': 3, 'totalTime': ...  A51
# 6     {'initial': 300, 'increment': 0, 'totalTime': ...  B22
# 9     {'initial': 180, 'increment': 2, 'totalTime': ...  D10
# ...                                                 ...  ...
# 1198   {'initial': 60, 'increment': 0, 'totalTime': 60}  A05
# 1201  {'initial': 900, 'increment': 15, 'totalTime':...  B52
# 1203  {'initial': 600, 'increment': 0, 'totalTime': ...  A04
# 1205  {'initial': 180, 'increment': 0, 'totalTime': ...  A16
# 1208  {'initial': 900, 'increment': 15, 'totalTime':...  A21
#
#                                            opening_name  white_player rating  \
# 0                               Catalan Opening: Closed  'chestroyer'   1075
# 2                   Caro-Kann Defense: Hillbilly Attack  'chestroyer'   1079
# 4                      Indian Defense: Budapest Defense  'chestroyer'   1470
# 6                    Sicilian Defense: Alapin Variation  'chestroyer'   1470
# 9                                          Slav Defense  'chestroyer'   1456
# ...                                                 ...           ...    ...
# 1198                Zukertort Opening: Lemberger Gambit  'chestroyer'   1500
# 1201          Sicilian Defense: Canal Attack, Main Line  'chestroyer'   1406
# 1203                     Zukertort Opening: Ross Gambit  'chestroyer'   1152
# 1205  English Opening: Anglo-Indian Defense, Queen's...  'chestroyer'   1500
# 1208  English Opening: King's English Variation, Rev...  'chestroyer'   1500
#
#          black_player rating.1
# 0      'elusivedemon'     1157
# 2     'katfishngrits'     1065
# 4        'kamikaze27'     1480
# 6           'mapelle'     1458
# 9         'dsjnzeroo'     1506
# ...               ...      ...
# 1198   'lordfarsomin'     1497
# 1201    'mateifaibis'     1424
# 1203        'ahmaadd'     1060
# 1205       'dancab07'     1506
# 1208       'mass1962'     1510
#
# [603 rows x 15 columns]

# %%
playing_white.winner.value_counts()
# Out:
# white    341
# black    241
# Name: winner, dtype: int64

# %%
playing_white.ECO.value_counts()
# Out:
# A40    47
# D20    37
# D00    28
# D06    28
# A20    26
#        ..
# D05     1
# A52     1
# D43     1
# A84     1
# B52     1
# Name: ECO, Length: 114, dtype: int64

# %%
playing_white.loc[playing_white.winner=='white', 'ECO'].value_counts()
# Out:
# A40    32
# D20    19
# C41    17
# A20    17
# D06    17
#        ..
# A27     1
# D40     1
# E61     1
# D94     1
# B13     1
# Name: ECO, Length: 84, dtype: int64

# %%
for column in columns_of_interest[0:4]:
    fig, ax = plt.subplots(figsize=(10, 8))
    ax = sns.barplot(x= playing_white[column].value_counts().index, y=playing_white[column].value_counts().values, palette='YlGnBu', ax=ax)
    plt.title(f'{column} Barplot')

# %%
fig, ax = plt.subplots(figsize=(25, 13))
ax = sns.barplot(x=playing_white['opening_name'].value_counts().values[0:20], 
                 y=playing_white['opening_name'].value_counts().index[0:20],
                 palette='YlGnBu')

# %% [markdown]
# # Playing as Black

# %%
playing_black = df.loc[df['black_player'] == player_name, :]
playing_black
# Out:
#       rated   variant      speed       perf                         createdAt  \
# 1      True  standard     bullet     bullet  2022-08-30 02:46:15.055000+00:00
# 3      True  standard      blitz      blitz  2022-08-30 02:24:49.912000+00:00
# 5      True  standard      blitz      blitz  2022-08-28 17:41:01.879000+00:00
# 7      True  standard      blitz      blitz  2022-08-28 17:29:03.628000+00:00
# 8      True  standard     bullet     bullet  2022-08-27 18:34:31.045000+00:00
# ...     ...       ...        ...        ...                               ...
# 1200   True  standard  classical  classical  2019-04-24 13:33:17.318000+00:00
# 1202   True  standard  classical  classical  2019-04-18 11:48:37.237000+00:00
# 1204   True  standard      rapid      rapid  2019-04-15 22:12:18.221000+00:00
# 1206   True  standard      rapid      rapid  2019-04-13 20:43:08.889000+00:00
# 1207   True  standard      rapid      rapid  2019-04-12 02:55:21.683000+00:00
#
#          status winner                                              moves  \
# 1     outoftime  black                                             Nc3 e5
# 3          mate  white  e4 c5 Nf3 e6 d4 cxd4 Nxd4 Nc6 Nc3 Nf6 Be3 d5 e...
# 5          mate  white  e4 e6 Nf3 d5 exd5 exd5 d4 c5 c4 cxd4 Qxd4 Nc6 ...
# 7        resign  black  e4 c5 d4 cxd4 c3 e5 cxd4 exd4 Qxd4 Nc6 Qd1 Nf6...
# 8     outoftime  black  e4 c5 c3 d6 d4 g6 d5 Nf6 f3 Bg7 Bb5+ Bd7 a4 Bx...
# ...         ...    ...                                                ...
# 1200       mate  white  e4 c6 Nf3 d5 e5 e6 g3 Bc5 d4 Bb6 Bg2 Ne7 O-O O...
# 1202       mate  white  e4 c5 Nc3 e6 Nf3 Nc6 d4 a6 d5 Nd4 Nxd4 cxd4 Qx...
# 1204    timeout  white  e4 c5 Bc4 e6 e5 d5 Bb5+ Bd7 Bxd7+ Nxd7 c3 Nxe5...
# 1206       mate  white  e4 c6 d4 d5 e5 e6 Nf3 Ne7 Nc3 Nd7 Bd3 f6 O-O N...
# 1207       mate  white  e4 c6 Bc4 d5 exd5 cxd5 Bb3 Bf5 d4 e6 h3 Nc6 c3...
#
#                                                   clock  ECO  \
# 1      {'initial': 60, 'increment': 0, 'totalTime': 60}  A00
# 3     {'initial': 180, 'increment': 2, 'totalTime': ...  B40
# 5     {'initial': 300, 'increment': 0, 'totalTime': ...  C00
# 7     {'initial': 300, 'increment': 0, 'totalTime': ...  B21
# 8      {'initial': 60, 'increment': 0, 'totalTime': 60}  B22
# ...                                                 ...  ...
# 1200  {'initial': 900, 'increment': 15, 'totalTime':...  B10
# 1202  {'initial': 900, 'increment': 15, 'totalTime':...  B23
# 1204  {'initial': 600, 'increment': 0, 'totalTime': ...  B20
# 1206  {'initial': 600, 'increment': 0, 'totalTime': ...  B12
# 1207  {'initial': 600, 'increment': 0, 'totalTime': ...  B10
#
#                                            opening_name          white_player  \
# 1                Van Geet Opening: Reversed Nimzowitsch       'tanishkpanara'
# 3              Sicilian Defense: Four Knights Variation  'gaspar_deepblueyev'
# 5                      French Defense: Knight Variation             'mapelle'
# 7     Sicilian Defense: Smith-Morra Gambit Declined,...            'evgen-99'
# 8                    Sicilian Defense: Alapin Variation   'donothurtmeplease'
# ...                                                 ...                   ...
# 1200                                  Caro-Kann Defense         'mateifaibis'
# 1202                           Sicilian Defense: Closed          'ma_diamond'
# 1204                   Sicilian Defense: Bowdler Attack         't-2wadbee-t'
# 1206               Caro-Kann Defense: Advance Variation           'emerson88'
# 1207                Caro-Kann Defense: Hillbilly Attack               'cyote'
#
#      rating  black_player rating.1
# 1      932,  'chestroyer'     1070
# 3      1576  'chestroyer'     1463
# 5      1452  'chestroyer'     1477
# 7      1461  'chestroyer'     1464
# 8      1080  'chestroyer'     1070
# ...     ...           ...      ...
# 1200   1433  'chestroyer'     1309
# 1202   1500  'chestroyer'     1504
# 1204   1241  'chestroyer'     1241
# 1206   1386  'chestroyer'     1346
# 1207   1546  'chestroyer'     1500
#
# [606 rows x 15 columns]

# %%
for column in columns_of_interest[0:4]:
    fig, ax = plt.subplots(figsize=(10, 8))
    ax = sns.barplot(x= playing_black[column].value_counts().index, y=playing_black[column].value_counts().values, palette='YlGnBu', ax=ax)
    plt.title(f'{column} Barplot')

# %%
fig, ax = plt.subplots(figsize=(25, 13))
ax = sns.barplot(x=playing_black['opening_name'].value_counts().values[0:20], 
                 y=playing_black['opening_name'].value_counts().index[0:20],
                 palette='YlGnBu')
