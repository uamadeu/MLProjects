# %%
import pandas as pd
import numpy as np
import os

# %%
def add_value_labels(ax, spacing=5):
    # Função adaptada do Stak Oveflow no link: https://stackoverflow.com/questions/28931224/how-to-add-value-labels-on-a-bar-chart
    # Esta função adiciona os value labels acima da barra no gráfico abaixo

    """Add labels to the end of each bar in a bar chart.

    Arguments:
        ax (matplotlib.axes.Axes): The matplotlib object containing the axes
            of the plot to annotate.
        spacing (int): The distance between the labels and the bars.
    """

    # For each bar: Place a label
    for rect in ax.patches:
        # Get X and Y placement of label from rect.
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2

        # Number of points between bar and label. Change to your liking.
        space = spacing
        # Vertical alignment for positive values
        va = 'bottom'

        # If value of bar is negative: Place label below bar
        if y_value < 0:
            # Invert space to place label below
            space *= -1
            # Vertically align label at top
            va = 'top'

        # Use Y value as label and format number with one decimal place
        label = "{:.2f}".format(y_value)

        # Create annotation
        ax.annotate(
            label,                      # Use `label` as label
            (x_value, y_value),         # Place label at end of the bar
            xytext=(0, space),          # Vertically shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            ha='center',                # Horizontally center label
            va=va)                      # Vertically align label differently for
                                        # positive and negative values.

# %% [markdown]
# # ETL

# %% [markdown]
# ## Getting data for each year

# %%
path = os.listdir(path=r"C:\Users\uliss\PycharmProjects\guppe\Github\MLProjects\WorldHappiness")[1:-1]
df_dict = {}
for idx, item in enumerate(path):
    df = pd.read_csv(item)
    df['Year'] = idx+2015
    df_dict[idx+2015] = df

# %% [markdown]
# ## Treating dataframes separately by year

# %% [markdown]
# ### 2015

# %%
df_2015 = df_dict[2015]
regions = dict([(x, y) for x, y in zip(df_2015.Country, df_2015.Region)])
df_2015_clean = df_2015.drop(['Region', 'Standard Error'], axis='columns')
df_2015_clean
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 153       Rwanda             154            3.465                   0.22208
# 154        Benin             155            3.340                   0.28665
# 155        Syria             156            3.006                   0.66320
# 156      Burundi             157            2.905                   0.01530
# 157         Togo             158            2.839                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# 1    1.40223                   0.94784  0.62877
# 2    1.36058                   0.87464  0.64938
# 3    1.33095                   0.88521  0.66973
# 4    1.32261                   0.90563  0.63297
# ..       ...                       ...      ...
# 153  0.77370                   0.42864  0.59201
# 154  0.35386                   0.31910  0.48450
# 155  0.47489                   0.72193  0.15684
# 156  0.41587                   0.22396  0.11850
# 157  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                          0.41978     0.29678            2.51738  2015
# 1                          0.14145     0.43630            2.70201  2015
# 2                          0.48357     0.34139            2.49204  2015
# 3                          0.36503     0.34699            2.46531  2015
# 4                          0.32957     0.45811            2.45176  2015
# ..                             ...         ...                ...   ...
# 153                        0.55191     0.22628            0.67042  2015
# 154                        0.08010     0.18260            1.63328  2015
# 155                        0.18906     0.47179            0.32858  2015
# 156                        0.10062     0.19727            1.83302  2015
# 157                        0.10731     0.16681            1.56726  2015
#
# [158 rows x 11 columns]

# %% [markdown]
# ### 2016

# %%
df_2016 = df_dict[2016]
df_2016_clean = df_2016.drop(['Lower Confidence Interval', 'Upper Confidence Interval', 'Region'], axis='columns')
df_2016_clean
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0        Denmark               1            7.526                   1.44178
# 1    Switzerland               2            7.509                   1.52733
# 2        Iceland               3            7.501                   1.42666
# 3         Norway               4            7.498                   1.57744
# 4        Finland               5            7.413                   1.40598
# ..           ...             ...              ...                       ...
# 152        Benin             153            3.484                   0.39499
# 153  Afghanistan             154            3.360                   0.38227
# 154         Togo             155            3.303                   0.28123
# 155        Syria             156            3.069                   0.74719
# 156      Burundi             157            2.905                   0.06831
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.16374                   0.79504  0.57941
# 1    1.14524                   0.86303  0.58557
# 2    1.18326                   0.86733  0.56624
# 3    1.12690                   0.79579  0.59609
# 4    1.13464                   0.81091  0.57104
# ..       ...                       ...      ...
# 152  0.10419                   0.21028  0.39747
# 153  0.11037                   0.17344  0.16430
# 154  0.00000                   0.24811  0.34678
# 155  0.14866                   0.62994  0.06912
# 156  0.23442                   0.15747  0.04320
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                          0.44453     0.36171            2.73939  2016
# 1                          0.41203     0.28083            2.69463  2016
# 2                          0.14975     0.47678            2.83137  2016
# 3                          0.35776     0.37895            2.66465  2016
# 4                          0.41004     0.25492            2.82596  2016
# ..                             ...         ...                ...   ...
# 152                        0.06681     0.20180            2.10812  2016
# 153                        0.07112     0.31268            2.14558  2016
# 154                        0.11587     0.17517            2.13540  2016
# 155                        0.17233     0.48397            0.81789  2016
# 156                        0.09419     0.20290            2.10404  2016
#
# [157 rows x 11 columns]

# %% [markdown]
# ### 2017

# %%
df_2017 = df_dict[2017]
df_2017 = df_2017.rename(columns={'Happiness.Rank': 'Happiness Rank', 'Happiness.Score': 'Happiness Score',
                        'Economy..GDP.per.Capita.': 'Economy (GDP per Capita)', 'Health..Life.Expectancy.': 'Health (Life Expectancy)',
                        'Trust..Government.Corruption.': 'Trust (Government Corruption)', 'Dystopia.Residual': 'Dystopia Residual'})
df_2017_clean = df_2017.drop(['Whisker.high', 'Whisker.low'], axis='columns')
df_2017_clean = df_2017_clean.iloc[:, [0, 1, 2, 3, 4, 5, 6, 8, 7, 9, 10]]
df_2017_clean
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# 1                    1.482383  1.551122                  0.792566  0.626007
# 2                    1.480633  1.610574                  0.833552  0.627163
# 3                    1.564980  1.516912                  0.858131  0.620071
# 4                    1.443572  1.540247                  0.809158  0.617951
# ..                        ...       ...                       ...       ...
# 150                  0.368746  0.945707                  0.326425  0.581844
# 151                  0.777153  0.396103                  0.500533  0.081539
# 152                  0.511136  1.041990                  0.364509  0.390018
# 153                  0.091623  0.629794                  0.151611  0.059901
# 154                  0.000000  0.000000                  0.018773  0.270842
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                         0.315964    0.362012           2.277027  2017
# 1                         0.400770    0.355280           2.313707  2017
# 2                         0.153527    0.475540           2.322715  2017
# 3                         0.367007    0.290549           2.276716  2017
# 4                         0.382612    0.245483           2.430182  2017
# ..                             ...         ...                ...   ...
# 150                       0.455220    0.252756           0.540061  2017
# 151                       0.151347    0.493664           1.061574  2017
# 152                       0.066035    0.354256           0.621130  2017
# 153                       0.084148    0.204435           1.683024  2017
# 154                       0.056565    0.280876           2.066005  2017
#
# [155 rows x 11 columns]

# %% [markdown]
# ### 2018

# %%
df_2018 = df_dict[2018]
df_2018 = df_2018.rename(columns={'Overall rank': 'Happiness Rank', 'Score': 'Happiness Score', 'Country or region': 'Country',
                        'GDP per capita': 'Economy (GDP per Capita)', 'Healthy life expectancy': 'Health (Life Expectancy)',
                        'Perceptions of corruption': 'Trust (Government Corruption)', 'Social support': 'Family',
                        'Freedom to make life choices': 'Freedom'})
df_2018_clean = df_2018.iloc[:, [1, 0, 2, 3, 4, 5, 6, 8, 7, 9]]
df_2018_clean
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                     Finland               1            7.632
# 1                      Norway               2            7.594
# 2                     Denmark               3            7.555
# 3                     Iceland               4            7.495
# 4                 Switzerland               5            7.487
# ..                        ...             ...              ...
# 151                     Yemen             152            3.355
# 152                  Tanzania             153            3.303
# 153               South Sudan             154            3.254
# 154  Central African Republic             155            3.083
# 155                   Burundi             156            2.905
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       1.305   1.592                     0.874    0.681
# 1                       1.456   1.582                     0.861    0.686
# 2                       1.351   1.590                     0.868    0.683
# 3                       1.343   1.644                     0.914    0.677
# 4                       1.420   1.549                     0.927    0.660
# ..                        ...     ...                       ...      ...
# 151                     0.442   1.073                     0.343    0.244
# 152                     0.455   0.991                     0.381    0.481
# 153                     0.337   0.608                     0.177    0.112
# 154                     0.024   0.000                     0.010    0.305
# 155                     0.091   0.627                     0.145    0.065
#
#      Trust (Government Corruption)  Generosity  Year
# 0                            0.393       0.202  2018
# 1                            0.340       0.286  2018
# 2                            0.408       0.284  2018
# 3                            0.138       0.353  2018
# 4                            0.357       0.256  2018
# ..                             ...         ...   ...
# 151                          0.064       0.083  2018
# 152                          0.097       0.270  2018
# 153                          0.106       0.224  2018
# 154                          0.038       0.218  2018
# 155                          0.076       0.149  2018
#
# [156 rows x 10 columns]

# %% [markdown]
# ### 2019

# %%
df_2019 = df_dict[2019]
df_2019 = df_2019.rename(columns={'Overall rank': 'Happiness Rank', 'Score': 'Happiness Score', 'Country or region': 'Country',
                        'GDP per capita': 'Economy (GDP per Capita)', 'Healthy life expectancy': 'Health (Life Expectancy)',
                        'Perceptions of corruption': 'Trust (Government Corruption)', 'Social support': 'Family',
                        'Freedom to make life choices': 'Freedom'})
df_2019_clean = df_2019.iloc[:, [1, 0, 2, 3, 4, 5, 6, 8, 7, 9]]
df_2019_clean
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                     Finland               1            7.769
# 1                     Denmark               2            7.600
# 2                      Norway               3            7.554
# 3                     Iceland               4            7.494
# 4                 Netherlands               5            7.488
# ..                        ...             ...              ...
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
# 155               South Sudan             156            2.853
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       1.340   1.587                     0.986    0.596
# 1                       1.383   1.573                     0.996    0.592
# 2                       1.488   1.582                     1.028    0.603
# 3                       1.380   1.624                     1.026    0.591
# 4                       1.396   1.522                     0.999    0.557
# ..                        ...     ...                       ...      ...
# 151                     0.359   0.711                     0.614    0.555
# 152                     0.476   0.885                     0.499    0.417
# 153                     0.350   0.517                     0.361    0.000
# 154                     0.026   0.000                     0.105    0.225
# 155                     0.306   0.575                     0.295    0.010
#
#      Trust (Government Corruption)  Generosity  Year
# 0                            0.393       0.153  2019
# 1                            0.410       0.252  2019
# 2                            0.341       0.271  2019
# 3                            0.118       0.354  2019
# 4                            0.298       0.322  2019
# ..                             ...         ...   ...
# 151                          0.411       0.217  2019
# 152                          0.147       0.276  2019
# 153                          0.025       0.158  2019
# 154                          0.035       0.235  2019
# 155                          0.091       0.202  2019
#
# [156 rows x 10 columns]

# %% [markdown]
# ### Concatenating dataframes

# %%
df_list = ['df_'+str(item)+'_clean' for item in range(2015, 2020)]
clean_dict = {df_list[0]: df_2015_clean, df_list[1]: df_2016_clean, df_list[2]: df_2017_clean,
              df_list[3]: df_2018_clean, df_list[4]: df_2019_clean}
clean_dict
# Out:
# {'df_2015_clean':          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
#  0    Switzerland               1            7.587                   1.39651
#  1        Iceland               2            7.561                   1.30232
#  2        Denmark               3            7.527                   1.32548
#  3         Norway               4            7.522                   1.45900
#  4         Canada               5            7.427                   1.32629
#  ..           ...             ...              ...                       ...
#  153       Rwanda             154            3.465                   0.22208
#  154        Benin             155            3.340                   0.28665
#  155        Syria             156            3.006                   0.66320
#  156      Burundi             157            2.905                   0.01530
#  157         Togo             158            2.839                   0.20868
#
#        Family  Health (Life Expectancy)  Freedom  \
#  0    1.34951                   0.94143  0.66557
#  1    1.40223                   0.94784  0.62877
#  2    1.36058                   0.87464  0.64938
#  3    1.33095                   0.88521  0.66973
#  4    1.32261                   0.90563  0.63297
#  ..       ...                       ...      ...
#  153  0.77370                   0.42864  0.59201
#  154  0.35386                   0.31910  0.48450
#  155  0.47489                   0.72193  0.15684
#  156  0.41587                   0.22396  0.11850
#  157  0.13995                   0.28443  0.36453
#
#       Trust (Government Corruption)  Generosity  Dystopia Residual  Year
#  0                          0.41978     0.29678            2.51738  2015
#  1                          0.14145     0.43630            2.70201  2015
#  2                          0.48357     0.34139            2.49204  2015
#  3                          0.36503     0.34699            2.46531  2015
#  4                          0.32957     0.45811            2.45176  2015
#  ..                             ...         ...                ...   ...
#  153                        0.55191     0.22628            0.67042  2015
#  154                        0.08010     0.18260            1.63328  2015
#  155                        0.18906     0.47179            0.32858  2015
#  156                        0.10062     0.19727            1.83302  2015
#  157                        0.10731     0.16681            1.56726  2015
#
#  [158 rows x 11 columns],
#  'df_2016_clean':          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
#  0        Denmark               1            7.526                   1.44178
#  1    Switzerland               2            7.509                   1.52733
#  2        Iceland               3            7.501                   1.42666
#  3         Norway               4            7.498                   1.57744
#  4        Finland               5            7.413                   1.40598
#  ..           ...             ...              ...                       ...
#  152        Benin             153            3.484                   0.39499
#  153  Afghanistan             154            3.360                   0.38227
#  154         Togo             155            3.303                   0.28123
#  155        Syria             156            3.069                   0.74719
#  156      Burundi             157            2.905                   0.06831
#
#        Family  Health (Life Expectancy)  Freedom  \
#  0    1.16374                   0.79504  0.57941
#  1    1.14524                   0.86303  0.58557
#  2    1.18326                   0.86733  0.56624
#  3    1.12690                   0.79579  0.59609
#  4    1.13464                   0.81091  0.57104
#  ..       ...                       ...      ...
#  152  0.10419                   0.21028  0.39747
#  153  0.11037                   0.17344  0.16430
#  154  0.00000                   0.24811  0.34678
#  155  0.14866                   0.62994  0.06912
#  156  0.23442                   0.15747  0.04320
#
#       Trust (Government Corruption)  Generosity  Dystopia Residual  Year
#  0                          0.44453     0.36171            2.73939  2016
#  1                          0.41203     0.28083            2.69463  2016
#  2                          0.14975     0.47678            2.83137  2016
#  3                          0.35776     0.37895            2.66465  2016
#  4                          0.41004     0.25492            2.82596  2016
#  ..                             ...         ...                ...   ...
#  152                        0.06681     0.20180            2.10812  2016
#  153                        0.07112     0.31268            2.14558  2016
#  154                        0.11587     0.17517            2.13540  2016
#  155                        0.17233     0.48397            0.81789  2016
#  156                        0.09419     0.20290            2.10404  2016
#
#  [157 rows x 11 columns],
#  'df_2017_clean':                       Country  Happiness Rank  Happiness Score  \
#  0                      Norway               1            7.537
#  1                     Denmark               2            7.522
#  2                     Iceland               3            7.504
#  3                 Switzerland               4            7.494
#  4                     Finland               5            7.469
#  ..                        ...             ...              ...
#  150                    Rwanda             151            3.471
#  151                     Syria             152            3.462
#  152                  Tanzania             153            3.349
#  153                   Burundi             154            2.905
#  154  Central African Republic             155            2.693
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
#  0                    1.616463  1.533524                  0.796667  0.635423
#  1                    1.482383  1.551122                  0.792566  0.626007
#  2                    1.480633  1.610574                  0.833552  0.627163
#  3                    1.564980  1.516912                  0.858131  0.620071
#  4                    1.443572  1.540247                  0.809158  0.617951
#  ..                        ...       ...                       ...       ...
#  150                  0.368746  0.945707                  0.326425  0.581844
#  151                  0.777153  0.396103                  0.500533  0.081539
#  152                  0.511136  1.041990                  0.364509  0.390018
#  153                  0.091623  0.629794                  0.151611  0.059901
#  154                  0.000000  0.000000                  0.018773  0.270842
#
#       Trust (Government Corruption)  Generosity  Dystopia Residual  Year
#  0                         0.315964    0.362012           2.277027  2017
#  1                         0.400770    0.355280           2.313707  2017
#  2                         0.153527    0.475540           2.322715  2017
#  3                         0.367007    0.290549           2.276716  2017
#  4                         0.382612    0.245483           2.430182  2017
#  ..                             ...         ...                ...   ...
#  150                       0.455220    0.252756           0.540061  2017
#  151                       0.151347    0.493664           1.061574  2017
#  152                       0.066035    0.354256           0.621130  2017
#  153                       0.084148    0.204435           1.683024  2017
#  154                       0.056565    0.280876           2.066005  2017
#
#  [155 rows x 11 columns],
#  'df_2018_clean':                       Country  Happiness Rank  Happiness Score  \
#  0                     Finland               1            7.632
#  1                      Norway               2            7.594
#  2                     Denmark               3            7.555
#  3                     Iceland               4            7.495
#  4                 Switzerland               5            7.487
#  ..                        ...             ...              ...
#  151                     Yemen             152            3.355
#  152                  Tanzania             153            3.303
#  153               South Sudan             154            3.254
#  154  Central African Republic             155            3.083
#  155                   Burundi             156            2.905
#
#       Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
#  0                       1.305   1.592                     0.874    0.681
#  1                       1.456   1.582                     0.861    0.686
#  2                       1.351   1.590                     0.868    0.683
#  3                       1.343   1.644                     0.914    0.677
#  4                       1.420   1.549                     0.927    0.660
#  ..                        ...     ...                       ...      ...
#  151                     0.442   1.073                     0.343    0.244
#  152                     0.455   0.991                     0.381    0.481
#  153                     0.337   0.608                     0.177    0.112
#  154                     0.024   0.000                     0.010    0.305
#  155                     0.091   0.627                     0.145    0.065
#
#       Trust (Government Corruption)  Generosity  Year
#  0                            0.393       0.202  2018
#  1                            0.340       0.286  2018
#  2                            0.408       0.284  2018
#  3                            0.138       0.353  2018
#  4                            0.357       0.256  2018
#  ..                             ...         ...   ...
#  151                          0.064       0.083  2018
#  152                          0.097       0.270  2018
#  153                          0.106       0.224  2018
#  154                          0.038       0.218  2018
#  155                          0.076       0.149  2018
#
#  [156 rows x 10 columns],
#  'df_2019_clean':                       Country  Happiness Rank  Happiness Score  \
#  0                     Finland               1            7.769
#  1                     Denmark               2            7.600
#  2                      Norway               3            7.554
#  3                     Iceland               4            7.494
#  4                 Netherlands               5            7.488
#  ..                        ...             ...              ...
#  151                    Rwanda             152            3.334
#  152                  Tanzania             153            3.231
#  153               Afghanistan             154            3.203
#  154  Central African Republic             155            3.083
#  155               South Sudan             156            2.853
#
#       Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
#  0                       1.340   1.587                     0.986    0.596
#  1                       1.383   1.573                     0.996    0.592
#  2                       1.488   1.582                     1.028    0.603
#  3                       1.380   1.624                     1.026    0.591
#  4                       1.396   1.522                     0.999    0.557
#  ..                        ...     ...                       ...      ...
#  151                     0.359   0.711                     0.614    0.555
#  152                     0.476   0.885                     0.499    0.417
#  153                     0.350   0.517                     0.361    0.000
#  154                     0.026   0.000                     0.105    0.225
#  155                     0.306   0.575                     0.295    0.010
#
#       Trust (Government Corruption)  Generosity  Year
#  0                            0.393       0.153  2019
#  1                            0.410       0.252  2019
#  2                            0.341       0.271  2019
#  3                            0.118       0.354  2019
#  4                            0.298       0.322  2019
#  ..                             ...         ...   ...
#  151                          0.411       0.217  2019
#  152                          0.147       0.276  2019
#  153                          0.025       0.158  2019
#  154                          0.035       0.235  2019
#  155                          0.091       0.202  2019
#
#  [156 rows x 10 columns]}

# %%
df_names = []

for item in clean_dict.keys():
    temp = clean_dict[item]
    df_names.append(temp)
    
df = pd.concat(df_names).reset_index().drop('index', axis='columns')
df['Region'] = [regions[item] if item in regions.keys() else '' for item in list(df.Country.values)]
df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 777                    Rwanda             152            3.334
# 778                  Tanzania             153            3.231
# 779               Afghanistan             154            3.203
# 780  Central African Republic             155            3.083
# 781               South Sudan             156            2.853
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 777                   0.35900  0.71100                   0.61400  0.55500
# 778                   0.47600  0.88500                   0.49900  0.41700
# 779                   0.35000  0.51700                   0.36100  0.00000
# 780                   0.02600  0.00000                   0.10500  0.22500
# 781                   0.30600  0.57500                   0.29500  0.01000
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year  \
# 0                          0.41978     0.29678            2.51738  2015
# 1                          0.14145     0.43630            2.70201  2015
# 2                          0.48357     0.34139            2.49204  2015
# 3                          0.36503     0.34699            2.46531  2015
# 4                          0.32957     0.45811            2.45176  2015
# ..                             ...         ...                ...   ...
# 777                        0.41100     0.21700                NaN  2019
# 778                        0.14700     0.27600                NaN  2019
# 779                        0.02500     0.15800                NaN  2019
# 780                        0.03500     0.23500                NaN  2019
# 781                        0.09100     0.20200                NaN  2019
#
#                  Region
# 0        Western Europe
# 1        Western Europe
# 2        Western Europe
# 3        Western Europe
# 4         North America
# ..                  ...
# 777  Sub-Saharan Africa
# 778  Sub-Saharan Africa
# 779       Southern Asia
# 780  Sub-Saharan Africa
# 781
#
# [782 rows x 12 columns]

# %%
df['Region'] = df['Region'].replace(to_replace="", value=np.nan)

# %%
for column in df.columns:
    print(f'{column} %Na: {df[column].isna().sum()/len(df[column])} - {df[column].isna().sum()} occurences')
# Out:
# Country %Na: 0.0 - 0 occurences
# Happiness Rank %Na: 0.0 - 0 occurences
# Happiness Score %Na: 0.0 - 0 occurences
# Economy (GDP per Capita) %Na: 0.0 - 0 occurences
# Family %Na: 0.0 - 0 occurences
# Health (Life Expectancy) %Na: 0.0 - 0 occurences
# Freedom %Na: 0.0 - 0 occurences
# Trust (Government Corruption) %Na: 0.0 - 0 occurences
# Generosity %Na: 0.0 - 0 occurences
# Dystopia Residual %Na: 0.3989769820971867 - 312 occurences
# Year %Na: 0.0 - 0 occurences
# Region %Na: 0.0319693094629156 - 25 occurences

# %% [markdown]
# ### Missing values
#
#
# #### Unfortunately our data presents values for Dystopia Residual only until 2017. We might drop this variable from our further analysis. Other variable with missing values like 'Region' and 'Trust' can be properly treated

# %%
## Manually input region data for the following countries
set(df.loc[df.Region.isna(), 'Country'])
# Out:
# {'Belize',
#  'Gambia',
#  'Hong Kong S.A.R., China',
#  'Namibia',
#  'North Macedonia',
#  'Northern Cyprus',
#  'Puerto Rico',
#  'Somalia',
#  'Somaliland Region',
#  'South Sudan',
#  'Taiwan Province of China',
#  'Trinidad & Tobago'}

# %%
df.loc[df['Trust (Government Corruption)'].isna(), :]
# Out:
#                   Country  Happiness Rank  Happiness Score  \
# 489  United Arab Emirates              20            6.774
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 489                     2.096   0.776                      0.67    0.284
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year  \
# 489                            NaN       0.186                NaN  2018
#
#                               Region
# 489  Middle East and Northern Africa

# %%
df.loc[df.Country=='United Arab Emirates', ['Year', 'Trust (Government Corruption)']]
# Out:
#      Year  Trust (Government Corruption)
# 19   2015                        0.38583
# 185  2016                        0.35561
# 335  2017                        0.32449
# 489  2018                            NaN
# 646  2019                        0.18200

# %% [markdown]
# #### We only got one missing value for Trust variable.
# #### This is a value for United Arab Emirates during 2018. Since there's a clearly negative progression over the years for this country we might interpolate values between 2017 and 2019 to evaluate the corresponding  Trust value for 2018 in United Arab Emirates.
#
# #### Looking to our values between 2015 and 2019 it's noticeable that Trust variable decrease almost linearly between 2015 and 2017. That doesn't seem to be the case between 2017 and 2019 in which values dropped almost to it's half in 2 years. Due to the abrupt decrease between 2017 and 2019 it's better to assume a quadratic evolution for our interpolation

# %%
pd.Series(df.loc[df.Country=='United Arab Emirates', 'Trust (Government Corruption)']).interpolate(method='quadratic')
# Out:
# 19     0.385830
# 185    0.355610
# 335    0.324490
# 489    0.268219
# 646    0.182000
# Name: Trust (Government Corruption), dtype: float64

# %%
df['Trust (Government Corruption)'] = df['Trust (Government Corruption)'].fillna(0.268219)
df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 777                    Rwanda             152            3.334
# 778                  Tanzania             153            3.231
# 779               Afghanistan             154            3.203
# 780  Central African Republic             155            3.083
# 781               South Sudan             156            2.853
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 777                   0.35900  0.71100                   0.61400  0.55500
# 778                   0.47600  0.88500                   0.49900  0.41700
# 779                   0.35000  0.51700                   0.36100  0.00000
# 780                   0.02600  0.00000                   0.10500  0.22500
# 781                   0.30600  0.57500                   0.29500  0.01000
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year  \
# 0                          0.41978     0.29678            2.51738  2015
# 1                          0.14145     0.43630            2.70201  2015
# 2                          0.48357     0.34139            2.49204  2015
# 3                          0.36503     0.34699            2.46531  2015
# 4                          0.32957     0.45811            2.45176  2015
# ..                             ...         ...                ...   ...
# 777                        0.41100     0.21700                NaN  2019
# 778                        0.14700     0.27600                NaN  2019
# 779                        0.02500     0.15800                NaN  2019
# 780                        0.03500     0.23500                NaN  2019
# 781                        0.09100     0.20200                NaN  2019
#
#                  Region
# 0        Western Europe
# 1        Western Europe
# 2        Western Europe
# 3        Western Europe
# 4         North America
# ..                  ...
# 777  Sub-Saharan Africa
# 778  Sub-Saharan Africa
# 779       Southern Asia
# 780  Sub-Saharan Africa
# 781                 NaN
#
# [782 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        782 non-null    object
#  1   Happiness Rank                 782 non-null    int64
#  2   Happiness Score                782 non-null    float64
#  3   Economy (GDP per Capita)       782 non-null    float64
#  4   Family                         782 non-null    float64
#  5   Health (Life Expectancy)       782 non-null    float64
#  6   Freedom                        782 non-null    float64
#  7   Trust (Government Corruption)  782 non-null    float64
#  8   Generosity                     782 non-null    float64
#  9   Dystopia Residual              470 non-null    float64
#  10  Year                           782 non-null    int64
#  11  Region                         757 non-null    object
# dtypes: float64(8), int64(2), object(2)
# memory usage: 73.4+ KB

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Motivation
#
# #### Discover through the data if there's any relationship between overall happiness (Hapiness Score) and each of the other variables. Is there any variable that has a bigger influence on the following data? What kind of patterns are hidden through the data that can help us understand income distribution all over the world?
#
# #### Points of study:
# ##### 1. Score x variables
# ##### 2. Statistical analysis grouping by year and region
# ##### 3. Economy influence
# ##### 4. Evolution through the years
# ##### 5. Given a country plot respective analysis and compare with a list of countries

# %% [markdown]
# ### 1. Score x Variables

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
corr = df.drop('Happiness Rank', axis='columns').corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Economy, Health and Family have the greatest correlation with Happiness Score

# %% [markdown]
# ### 2. Statistical analysis

# %% [markdown]
# #### By year

# %%
df.groupby('Year').agg(['mean', 'median', 'std', 'count'])
# Out:
#      Happiness Rank                         Happiness Score                    \
#                mean median        std count            mean  median       std
# Year
# 2015      79.493671   79.5  45.754363   158        5.375734  5.2325  1.145010
# 2016      78.980892   79.0  45.466030   157        5.382185  5.3140  1.141674
# 2017      78.000000   78.0  44.888751   155        5.354019  5.2790  1.131230
# 2018      78.500000   78.5  45.177428   156        5.375917  5.3780  1.119506
# 2019      78.500000   78.5  45.177428   156        5.407096  5.3795  1.113120
#
#            Economy (GDP per Capita)            ...  \
#      count                     mean    median  ...
# Year                                           ...
# 2015   158                 0.846137  0.910245  ...
# 2016   157                 0.953880  1.027800  ...
# 2017   155                 0.984718  1.064578  ...
# 2018   156                 0.891449  0.949500  ...
# 2019   156                 0.905147  0.960000  ...
#
#      Trust (Government Corruption)       Generosity                            \
#                                std count       mean    median       std count
# Year
# 2015                      0.120034   158   0.237296  0.216130  0.126685   158
# 2016                      0.111038   157   0.242635  0.222450  0.133756   157
# 2017                      0.101661   155   0.246883  0.231538  0.134780   155
# 2018                      0.096990   156   0.181006  0.174000  0.098471   156
# 2019                      0.094538   156   0.184846  0.177500  0.095254   156
#
#      Dystopia Residual
#                   mean    median       std count
# Year
# 2015          2.098977  2.095415  0.553550   158
# 2016          2.325807  2.290740  0.542220   157
# 2017          1.850238  1.832910  0.500028   155
# 2018               NaN       NaN       NaN     0
# 2019               NaN       NaN       NaN     0
#
# [5 rows x 36 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 12))
sns.histplot(data=df, x='Happiness Score', palette='mako', kde=True)
plt.title('Score Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fig, ax = plt.subplots(figsize=(20, 12))
sns.boxplot(data=df, x='Happiness Score', palette='mako')
plt.title('Score Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.DataFrame(df['Happiness Score'].describe())
# Out:
#        Happiness Score
# count       782.000000
# mean          5.379018
# std           1.127456
# min           2.693000
# 25%           4.509750
# 50%           5.322000
# 75%           6.189500
# max           7.769000

# %%
print(f"Kurtosis: {df['Happiness Score'].kurtosis()}")
print(f"Skewness: {df['Happiness Score'].skew()}")
# Out:
# Kurtosis: -0.7610545865625724
# Skewness: 0.035859433273691114

# %%
for item in ['mean', 'median', 'std', 'min', 'max']:
    fig, ax = plt.subplots(figsize=(10, 6))
    sns.barplot(x=df.groupby('Year')['Happiness Score'].agg(item).index,
                y=df.groupby('Year')['Happiness Score'].agg(item).values,
                palette = 'magma')
    add_value_labels(ax)
    plt.title(f'{item} progression over the years ')

# %%
amp = df.groupby('Year')['Happiness Score'].agg(max) - df.groupby('Year')['Happiness Score'].agg(min)
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x=amp.index,
            y=amp.values,
            palette = 'magma')
add_value_labels(ax)
plt.title(f'Inequality progression over the years ')
# Out:
# Text(0.5, 1.0, 'Inequality progression over the years ')

# %% [markdown]
# ### By Region

# %%
df_region = df.groupby('Region').agg(['mean', 'median', 'std', 'count'])
df_region
# Out:
#                                 Happiness Rank                          \
#                                           mean median        std count
# Region
# Australia and New Zealand             9.100000    9.0   1.100505    10
# Central and Eastern Europe           75.631944   73.0  26.800153   144
# Eastern Asia                         66.321429   65.0  22.537300    28
# Latin America and Caribbean          50.066667   43.0  30.342996   105
# Middle East and Northern Africa      79.562500   83.0  41.401961    96
# North America                        11.300000   11.0   5.143496    10
# Southeastern Asia                    80.545455   81.5  35.452198    44
# Southern Asia                       112.457143  115.0  23.309103    35
# Sub-Saharan Africa                  128.131868  132.0  20.856897   182
# Western Europe                       26.116505   17.0  26.364452   103
#
#                                 Happiness Score                          \
#                                            mean  median       std count
# Region
# Australia and New Zealand              7.294600  7.2965  0.030787    10
# Central and Eastern Europe             5.428875  5.5025  0.587102   144
# Eastern Asia                           5.630464  5.6545  0.472521    28
# Latin America and Caribbean            6.012876  6.1250  0.734252   105
# Middle East and Northern Africa        5.337208  5.2745  1.022185    96
# North America                          7.174700  7.1985  0.204057    10
# Southeastern Asia                      5.335227  5.2705  0.801819    44
# Southern Asia                          4.580657  4.5650  0.587753    35
# Sub-Saharan Africa                     4.174165  4.1895  0.584338   182
# Western Europe                         6.759311  6.9400  0.747602   103
#
#                                 Economy (GDP per Capita)            ...  \
#                                                     mean    median  ...
# Region                                                              ...
# Australia and New Zealand                       1.356197  1.350330  ...
# Central and Eastern Europe                      1.018734  1.065789  ...
# Eastern Asia                                    1.219484  1.292490  ...
# Latin America and Caribbean                     0.934474  0.981240  ...
# Middle East and Northern Africa                 1.102633  1.055830  ...
# North America                                   1.422037  1.415500  ...
# Southeastern Asia                               0.893340  0.809585  ...
# Southern Asia                                   0.638813  0.652000  ...
# Sub-Saharan Africa                              0.451437  0.376923  ...
# Western Europe                                  1.372702  1.354950  ...
#
#                                 Generosity       Dystopia Residual            \
#                                        std count              mean    median
# Region
# Australia and New Zealand         0.069565    10          2.277401  2.265355
# Central and Eastern Europe        0.087819   144          2.026250  2.000730
# Eastern Asia                      0.110040    28          1.725848  1.785389
# Latin America and Caribbean       0.095095   105          2.587155  2.671390
# Middle East and Northern Africa   0.111032    96          2.014162  1.970950
# North America                     0.070902    10          2.466653  2.480935
# Southeastern Asia                 0.182852    44          1.783628  1.885210
# Southern Asia                     0.103531    35          1.961907  1.978736
# Sub-Saharan Africa                0.075769   182          1.946139  1.946175
# Western Europe                    0.129454   103          2.158601  2.138506
#
#                                                         Year          \
#                                       std count         mean  median
# Region
# Australia and New Zealand        0.205096     6  2017.000000  2017.0
# Central and Eastern Europe       0.475399    87  2016.986111  2017.0
# Eastern Asia                     0.548172    16  2017.000000  2017.0
# Latin America and Caribbean      0.527585    65  2016.942857  2017.0
# Middle East and Northern Africa  0.559777    58  2016.979167  2017.0
# North America                    0.231035     6  2017.000000  2017.0
# Southeastern Asia                0.431017    26  2017.000000  2017.0
# Southern Asia                    0.731617    21  2017.000000  2017.0
# Sub-Saharan Africa               0.527363   110  2016.967033  2017.0
# Western Europe                   0.396561    63  2016.970874  2017.0
#
#
#                                       std count
# Region
# Australia and New Zealand        1.490712    10
# Central and Eastern Europe       1.414145   144
# Eastern Asia                     1.490712    28
# Latin America and Caribbean      1.419836   105
# Middle East and Northern Africa  1.428869    96
# North America                    1.490712    10
# Southeastern Asia                1.446728    44
# Southern Asia                    1.434860    35
# Sub-Saharan Africa               1.437082   182
# Western Europe                   1.417373   103
#
# [10 rows x 40 columns]

# %%
items = [item for item in df_region.index]
fig, axes = plt.subplots(5, 2, figsize=(15, 30))
axes = axes.flatten()
for item, ax in zip(items, axes):
    ax=sns.scatterplot(data=df.loc[df.Region==item, :], x='Economy (GDP per Capita)', y='Happiness Score', ax=ax) 
    ax.set_title(f'Economy x Score - {item}')

# %%
items = [item for item in df_region.index]
fig, axes = plt.subplots(5, 2, figsize=(15, 30))
axes = axes.flatten()
for item, ax in zip(items, axes):
    ax=sns.scatterplot(data=df.loc[df.Region==item, :], x='Health (Life Expectancy)', y='Happiness Score', ax=ax) 
    ax.set_title(f'Health x Score - {item}')

# %%
items = [item for item in df_region.index]
fig, axes = plt.subplots(5, 2, figsize=(15, 30))
axes = axes.flatten()
for item, ax in zip(items, axes):
    ax=sns.scatterplot(data=df.loc[df.Region==item, :], x='Economy (GDP per Capita)', y='Health (Life Expectancy)', ax=ax) 
    ax.set_title(f'Economy x Health - {item}')

# %%
fix, ax = plt.subplots(figsize=(12, 12))
sns.countplot(data=df, x='Region', order=df.Region.value_counts(ascending=True).index, palette='YlGnBu')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
fix, ax = plt.subplots(figsize=(12, 12))
sns.barplot(data=df, x='Region', y='Happiness Score', palette='YlGnBu')
add_value_labels(ax)

# %% [markdown]
# ### 3. Economy Influence

# %%
for year in df.Year.unique():
    fig, ax = plt.subplots(figsize=(12, 12))
    sns.barplot(x=df.loc[df.Year==year, :]['Country'][0:10], y=df.loc[df.Year==year, :]['Economy (GDP per Capita)'][0:10], palette='icefire')
    plt.title(f'Top 10 Happiness by Economy stats - {year}')
    add_value_labels(ax)
    plt.show()

# %% [markdown]
# ### 4. Evolution through the years

# %%
for item in df.columns[2:-2]:
    fig, ax = plt.subplots(figsize=(12, 6))
    sns.lineplot(x=df.Year, y=df[item])
    plt.title(f'{item} evolution over the years')
    plt.xticks([2015, 2016, 2017, 2018, 2019])

# %% [markdown]
# ### 5. Country data

# %%
def country_data(df, country):
    df = df.loc[df.Country == country, :]
    minval = df.loc[df.Country == country, :]['Happiness Rank'].min() 
    maxval = df.loc[df.Country == country, :]['Happiness Rank'].max()
    for item in df.columns[1:-2]:
        if item != 'Happiness Rank':
            fig, ax = plt.subplots(figsize=(15, 8))
            sns.lineplot(x=df.Year, y=df[item])
            plt.title(f'{item} evolution over the years - {country}')
            plt.xticks([2015, 2016, 2017, 2018, 2019])
            plt.show()
        else:
            fig, ax = plt.subplots(figsize=(15, 8))
            sns.lineplot(x=df.Year, y=df[item])
            plt.title(f'{item} evolution over the years - {country}')
            plt.ylim(maxval, minval)
            plt.xticks([2015, 2016, 2017, 2018, 2019])
            plt.show()
        
def compare_country(df, country):
    df = df.loc[df.Country.isin(country), :]
    minval = df.loc[df.Country.isin(country), :]['Happiness Rank'].min() 
    maxval = df.loc[df.Country.isin(country), :]['Happiness Rank'].max()
    for item in df.columns[1:-2]:
        if item != 'Hapiness Rank':
            fig, ax = plt.subplots(figsize=(15, 8))
            sns.lineplot(x=df.Year, y=df[item], hue=df.Country, palette='Pastel1')
            plt.title(f'{item} evolution over the years - {country}')
            plt.xticks([2015, 2016, 2017, 2018, 2019])
            plt.show()
        else:
            fig, ax = plt.subplots(figsize=(15, 8))
            sns.lineplot(x=df.Year, y=df[item], hue=df.Country, palette='Pastel1')
            plt.title(f'{item} evolution over the years - {country}')
            plt.ylim(maxval, minval)
            plt.xticks([2015, 2016, 2017, 2018, 2019])
            plt.show()

# %%
country_data(df, 'Brazil')

# %%
compare_country(df, ['Brazil', 'Finland'])

# %%
g8 = ['France', 'Germany', 'Italy', 'United Kingdom', 'Japan', 'United States', 'Canada', 'Russia']

# %%
compare_country(df, g8)
