# %% [markdown]
# Let's study how diamond prices are affected by their properties so we can then apply some machine learning models and predict prices.

# %% [markdown]
# # 1. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. EDA

# %%
diamond_df = pd.read_csv('Diamonds Prices2022.csv', index_col=0)

# %%
diamond_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [53943 rows x 10 columns]

# %%
diamond_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53943 entries, 1 to 53943
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53943 non-null  float64
#  1   cut      53943 non-null  object
#  2   color    53943 non-null  object
#  3   clarity  53943 non-null  object
#  4   depth    53943 non-null  float64
#  5   table    53943 non-null  float64
#  6   price    53943 non-null  int64
#  7   x        53943 non-null  float64
#  8   y        53943 non-null  float64
#  9   z        53943 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# ## 2.1 Statistical analysis

# %%
diamond_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean       0.797935     61.749322     57.457251   3932.734294      5.731158
# std        0.473999      1.432626      2.234549   3989.338447      1.121730
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53943.000000  53943.000000
# mean       5.734526      3.538730
# std        1.142103      0.705679
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# - From the describe() function we notice that 'carat' and 'price' variables has both a great cardinality. We can infer that from the comparison between their mean values and standard deviation. This will be discussed again in a further analysis.
# - Both 'depth' and 'table' variables have low cardinality, with values close to the mean, despite having some outliers. The median value on the next cell helps to confirm this fact, since median value for both variables is pretty close to the mean.
# - It's alarming the fact that the 4º quartile for price varies from 5324 to 18823 while the other three quartiles all together vary from 326 to 5324. A further analysis will tell the right approach to deal with the outliers.

# %%
diamond_df.median(numeric_only=True)
# Out:
# carat       0.70
# depth      61.80
# table      57.00
# price    2401.00
# x           5.70
# y           5.71
# z           3.53
# dtype: float64

# %%
diamond_df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# There's no missing values on this dataset

# %% [markdown]
# ## 2.1 Features analysis

# %%
for category in ['cut', 'clarity', 'color']:
    print(f'Values from category: {category}')
    print(diamond_df[category].value_counts().head(25))
    print('-'*100)
# Out:
# Values from category: cut
# Ideal        21551
# Premium      13793
# Very Good    12083
# Good          4906
# Fair          1610
# Name: cut, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Values from category: clarity
# SI1     13067
# VS2     12259
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Values from category: color
# G    11292
# E     9799
# F     9543
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
sns.heatmap(diamond_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - It's noticeable that carat and the three dimensional variables x, y, z have the greatest correlation with the diamond prices, which means that both carat and diamond size are the variables that make diamond prices vary the most.
# - Once x, y and z variable have correlation greater than 0.9 between themselves, might be better the change them to a new variable called volume. For that we could approximate the diamond volume by a pyramid.

# %%
diamond_df['delta'] = diamond_df['x'] - diamond_df['y']
diamond_df['delta'].describe()
diamond_df.loc[diamond_df['delta']==-50.81, :]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 24068    2.0  Premium     H     SI2   58.9   57.0  12210  8.09  58.9  8.06
#
#        delta
# 24068 -50.81

# %% [markdown]
# - Despite the fact that there are no missing values, there might be some occult missing values.
# - We notice this fact when analyzing the index 11182. Both x and z dimensional variables are 0.00.
# - It seems that they might be unknown so they were both inputed as 0.
# - We could treat these values by changing them to the x and z median values, but since it's just one sample that has 0.00 values, let's just drop them out.

# %%
diamond_df.loc[abs(diamond_df['delta'])>0.5, :]
# Out:
#        carat      cut color clarity  depth  table  price     x      y     z  \
# 2275    1.22  Premium     J     SI2   62.6   59.0   3156  6.79   4.24  3.76
# 11183   1.07    Ideal     F     SI2   61.6   56.0   4954  0.00   6.62  0.00
# 14030   1.22    Ideal     H     SI2   61.1   57.0   5703  6.90   5.92  4.22
# 14345   1.22    Ideal     H     SI2   61.1   57.0   5807  6.90   5.92  4.22
# 15236   1.12  Premium     H     VS1   61.6   58.0   6115  6.64   4.11  3.70
# 17827   1.51     Fair     H     VS2   65.6   56.0   7188  7.08   4.70  4.00
# 19503   1.57     Fair     H     VS1   67.3   66.0   8133  7.85   5.75  3.87
# 24068   2.00  Premium     H     SI2   58.9   57.0  12210  8.09  58.90  8.06
# 27647   2.01     Fair     G     SI1   70.6   64.0  18574  7.43   6.64  4.69
# 33103   0.34     Good     E     VS2   57.0   61.0    816  6.65   4.61  2.64
# 34283   0.39  Premium     H     SI2   61.2   58.0    468  4.51   6.02  4.44
# ...

# %%
diamond_df.iloc[11182, :]
# Out:
# carat       1.07
# cut        Ideal
# color          F
# clarity      SI2
# depth       61.6
# table       56.0
# price       4954
# x            0.0
# y           6.62
# z            0.0
# delta      -6.62
# Name: 11183, dtype: object

# %%
diamond_df.drop(11182, axis='rows', inplace=True)

# %% [markdown]
# Based on the size of the sample and the analysis of delta = x-y value, we can approximate the base area of the diamond by a hexagon inscribed within a square of side x.

# %%
def hexagonside(a):
 
    # Side cannot be negative
    if (a < 0):
        return -1;
 
    # Side of the hexagon
    x = 0.5176 * a;
    return x;

# %%
diamond_df['area'] = diamond_df['x'].apply(lambda x: hexagonside(x))
diamond_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
#        delta      area
# ...

# %%
diamond_df['volume'] = 1/3*diamond_df['area']*diamond_df['z']
diamond_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
#        delta      area    volume
# ...

# %% [markdown]
# Now that we have the volume variable calculated from the dimensions x, y and z, we should drop all the redundant variables.

# %%
df2 = diamond_df.drop(['x', 'y', 'z', 'delta', 'area'], axis='columns')
df2
# Out:
#        carat        cut color clarity  depth  table  price    volume
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  1.656061
# 2       0.21    Premium     E     SI1   59.8   61.0    326  1.550367
# 3       0.23       Good     E     VS1   56.9   65.0    327  1.614136
# 4       0.29    Premium     I     VS2   62.4   58.0    334  1.905803
# 5       0.31       Good     J     SI2   63.3   58.0    335  2.059185
# ...      ...        ...   ...     ...    ...    ...    ...       ...
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  3.968439
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  3.661364
# 53941   0.71    Premium     E     SI1   60.5   55.0   2756  3.486398
# 53942   0.71    Premium     F     SI1   59.8   62.0   2756  3.396871
# 53943   0.70  Very Good     E     VS2   60.5   59.0   2757  3.418524
#
# [53942 rows x 8 columns]

# %%
sns.heatmap(df2.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(15, 10))
ax = sns.scatterplot(x=diamond_df.carat, y=diamond_df.price, hue=diamond_df.cut)
plt.title('Price x Carat Scatter Distribution')
# Out:
# Text(0.5, 1.0, 'Price x Carat Scatter Distribution')

# %%
price = diamond_df.price.sort_values()
sns.lineplot(x=price.reset_index().index, y=price)
# Out:
# <AxesSubplot:ylabel='price'>

# %%
diamond_df.loc[diamond_df['price']>=10000, :].describe()
# Out:
#              carat       depth        table         price            x  \
# count  5223.000000  5223.00000  5223.000000   5223.000000  5223.000000
# mean      1.741066    61.64844    57.893356  13639.760482     7.671503
# std       0.379109     1.44203     2.213577   2518.043556     0.589378
# min       1.000000    55.20000    50.000000  10000.000000     0.000000
# 25%       1.510000    60.80000    56.000000  11403.500000     7.320000
# 50%       1.690000    61.80000    58.000000  13234.000000     7.610000
# 75%       2.020000    62.50000    59.000000  15729.000000     8.120000
# max       5.010000    70.60000    95.000000  18823.000000    10.740000
#
#                  y            z        delta         area       volume
# count  5223.000000  5223.000000  5223.000000  5223.000000  5223.000000
# mean      7.673259     4.722608    -0.001756     3.970770     6.285470
# std       0.914230     0.396862     0.706387     0.305062     0.942744
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = plt.hist(diamond_df.price, bins=100)
plt.title('Diamond Price Distribution')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = plt.hist(diamond_df.carat, bins=50)
plt.title('Carat Distribution')
plt.xlabel('Carat')
# Out:
# Text(0.5, 0, 'Carat')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = sns.barplot(x=df2.cut, y=df2.price)
plt.title('Price x Cut type')
# Out:
# Text(0.5, 1.0, 'Price x Cut type')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = sns.barplot(x=df2.clarity, y=df2.price, order = ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1'])
plt.title('Price x Clarity')
# Out:
# Text(0.5, 1.0, 'Price x Clarity')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = sns.barplot(x=df2.color, y=df2.price, order = ['D', 'E', 'F', 'G', 'H', 'I', 'J'])
plt.title('Price x Color')
# Out:
# Text(0.5, 1.0, 'Price x Color')

# %%
sns.pairplot(df2)

# %% [markdown]
# ## 2.2 Outliers Analysis

# %%
sns.boxplot(x=diamond_df.clarity, y=diamond_df.price)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
sns.boxplot(x=diamond_df.color, y=diamond_df.price)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
sns.boxplot(x=diamond_df.cut, y=diamond_df.price)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
print(f'Mean price: {diamond_df.price.mean()}, Std: {diamond_df.price.std()}')
print(f'Range to define outliers (2*Std) : From 0 to {diamond_df.price.mean() + 2*diamond_df.price.std()}')
# Out:
# Mean price: 3932.7153794816654, Std: 3989.373006680852
# Range to define outliers (2*Std) : From 0 to 11911.46139284337

# %% [markdown]
# - Lets try to drop from our analysis the price values above 12000.

# %%
diamond_df.loc[diamond_df['price']>=12000, :]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 23897   1.50  Very Good     E     SI1   60.4   59.0  12000  7.35  7.39  4.45
# 23898   1.57      Ideal     H     VS2   61.8   55.0  12004  7.45  7.49  4.62
# 23899   1.50  Very Good     G     VS1   63.4   59.0  12005  7.25  7.19  4.58
# 23900   1.31      Ideal     G     VS1   61.6   57.0  12008  6.99  7.04  4.32
# 23901   1.50      Ideal     G     SI1   61.0   57.0  12009  7.38  7.41  4.51
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
#        delta      area    volume
# ...

# %% [markdown]
# - There's a total amount of 3463 defined outliers, which represents 6.42% of the original sample.

# %%
df3 = df2.loc[df2['price']<=12000, :]
df3
# Out:
#        carat        cut color clarity  depth  table  price    volume
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  1.656061
# 2       0.21    Premium     E     SI1   59.8   61.0    326  1.550367
# 3       0.23       Good     E     VS1   56.9   65.0    327  1.614136
# 4       0.29    Premium     I     VS2   62.4   58.0    334  1.905803
# 5       0.31       Good     J     SI2   63.3   58.0    335  2.059185
# ...      ...        ...   ...     ...    ...    ...    ...       ...
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  3.968439
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  3.661364
# 53941   0.71    Premium     E     SI1   60.5   55.0   2756  3.486398
# 53942   0.71    Premium     F     SI1   59.8   62.0   2756  3.396871
# 53943   0.70  Very Good     E     VS2   60.5   59.0   2757  3.418524
#
# [50479 rows x 8 columns]

# %% [markdown]
# ## 2.3 Boxplot after remove outliers

# %%
sns.boxplot(x=df3.cut, y=df3.price)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.boxplot(x=df3.cut, y=df3.price)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.boxplot(x=df3.cut, y=df3.price)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
df3.describe()
# Out:
#               carat         depth         table         price        volume
# count  50479.000000  50479.000000  50479.000000  50479.000000  50479.000000
# mean       0.725064     61.755809     57.422800   3172.803423      3.430169
# std        0.385345      1.430698      2.229411   2783.725565      1.221865
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.380000     61.100000     56.000000    911.000000      2.324128
# 50%        0.700000     61.800000     57.000000   2161.000000      3.372337
# 75%        1.010000     62.500000     59.000000   4679.000000      4.411125
# max        3.650000     79.000000     79.000000  12000.000000     28.091187

# %% [markdown]
# - There's still many outliers but the difference is noticeable and for sure the error of our models will be lower.

# %% [markdown]
# # 3. Machine Learning

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# - Since table and depth variables doesn't have a good correlation between price, might be better to simply drop them from our model.

# %%
x = df3.drop(['price', 'table', 'depth'], axis=1)
y = df3.price
x
# Out:
#        carat        cut color clarity    volume
# 1       0.23      Ideal     E     SI2  1.656061
# 2       0.21    Premium     E     SI1  1.550367
# 3       0.23       Good     E     VS1  1.614136
# 4       0.29    Premium     I     VS2  1.905803
# 5       0.31       Good     J     SI2  2.059185
# ...      ...        ...   ...     ...       ...
# 53939   0.86    Premium     H     SI2  3.968439
# 53940   0.75      Ideal     D     SI2  3.661364
# 53941   0.71    Premium     E     SI1  3.486398
# 53942   0.71    Premium     F     SI1  3.396871
# 53943   0.70  Very Good     E     VS2  3.418524
#
# [50479 rows x 5 columns]

# %% [markdown]
# ## 3.1 Dummies

# %%
x_dummy = pd.get_dummies(x, columns=['cut', 'color', 'clarity'])
x_dummy
# Out:
#        carat    volume  cut_Fair  cut_Good  cut_Ideal  cut_Premium  \
# 1       0.23  1.656061         0         0          1            0
# 2       0.21  1.550367         0         0          0            1
# 3       0.23  1.614136         0         1          0            0
# 4       0.29  1.905803         0         0          0            1
# 5       0.31  2.059185         0         1          0            0
# ...      ...       ...       ...       ...        ...          ...
# 53939   0.86  3.968439         0         0          0            1
# 53940   0.75  3.661364         0         0          1            0
# 53941   0.71  3.486398         0         0          0            1
# 53942   0.71  3.396871         0         0          0            1
# 53943   0.70  3.418524         0         0          0            0
#
#        cut_Very Good  color_D  color_E  color_F  ...  color_I  color_J  \
# 1                  0        0        1        0  ...        0        0
# ...

# %%
y
# Out:
# 1         326
# 2         326
# 3         327
# 4         334
# 5         335
#          ...
# 53939    2757
# 53940    2757
# 53941    2756
# 53942    2756
# 53943    2757
# Name: price, Length: 50479, dtype: int64

# %%
categorical = ['cut', 'color', 'clarity']
numerical = ['carat', 'depth', 'table', 'volume']

# %% [markdown]
# ## 3.2 Loading models and pipelines

# %%
ada = AdaBoostRegressor()
rf = RandomForestRegressor()
lr = LinearRegression()

pipe1 = make_pipeline(StandardScaler(), ada)
pipe2 = make_pipeline(StandardScaler(), rf)
pipe3 = make_pipeline(StandardScaler(), lr)

# %% [markdown]
# ## 3.3 Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_dummy, y, test_size=0.3, random_state=42)

# %%
pipe1.fit(x_train, y_train)
y_pred = pipe1.predict(x_test)
kfold = KFold(n_splits=10)
s = cross_val_score(ada, x_train, y_train, cv=kfold)
s.mean()
# Out:
# 0.8826848358914068

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8809438535460785

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'mse: {mse}, mae: {mae}')
# Out:
# mse: 894808.2535794268, mae: 708.6250817162013

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(y_pred), max(y_test))
p2 = min(min(y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
pipe2.fit(x_train, y_train)
y_pred2 = pipe2.predict(x_test)
kfold = KFold(n_splits=10)
s = cross_val_score(rf, x_train, y_train, cv=kfold)
s.mean()
# Out:
# 0.9778005081896938

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.9776259019835427

# %%
mse = mean_squared_error(y_test, y_pred2)
mae = mean_absolute_error(y_test, y_pred2)
print(f'mse: {mse}, mae: {mae}')
# Out:
# mse: 168160.38623650253, mae: 235.23506568524652

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred2, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(y_pred2), max(y_test))
p2 = min(min(y_pred2), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
pipe3.fit(x_train, y_train)
y_pred3 = pipe3.predict(x_test)
kfold = KFold(n_splits=10)
s = cross_val_score(lr, x_train, y_train, cv=kfold)
s.mean()
# Out:
# 0.916628609790819

# %%
r2_score(y_test, y_pred3)
# Out:
# 0.9183060330375398

# %%
mse = mean_squared_error(y_test, y_pred3)
mae = mean_absolute_error(y_test, y_pred3)
print(f'mse: {mse}, mae: {mae}')
# Out:
# mse: 613999.6806796248, mae: 555.0607032565727

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred3, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(y_pred3), max(y_test))
p2 = min(min(y_pred3), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %% [markdown]
# # 4. Evaluation of models

# %% [markdown]
# - All three models performed great on training, with cross validated scores from 88% to 98%.
# - Although, both Mean Squared Error (MSE) and Mean Absolute Error (MAE) for testing samples are higher than expected. This means the model might have more outliers than expected.
# - The best model is the Random Forest Regressor with 98% accuracy during training.
# - Random Forest showed the significant lower values for MSE and MAE when compared to the other models.
# - After add topic 2.2 and remove some outliers from the analysis, the values of MSE and MAE for the three models reduced significantly. For instance, the AdaBoost was getting 1900000 MSE value before removing outliers and got 894808 MSE after.
