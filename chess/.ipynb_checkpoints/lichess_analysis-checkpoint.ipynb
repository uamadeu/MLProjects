# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Functions

# %%
def add_value_labels(ax, spacing=5):
    # Função adaptada do Stak Oveflow no link: https://stackoverflow.com/questions/28931224/how-to-add-value-labels-on-a-bar-chart
    # Esta função adiciona os value labels acima da barra no gráfico abaixo

    """Add labels to the end of each bar in a bar chart.

    Arguments:
        ax (matplotlib.axes.Axes): The matplotlib object containing the axes
            of the plot to annotate.
        spacing (int): The distance between the labels and the bars.
    """

    # For each bar: Place a label
    for rect in ax.patches:
        # Get X and Y placement of label from rect.
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2

        # Number of points between bar and label. Change to your liking.
        space = spacing
        # Vertical alignment for positive values
        va = 'bottom'

        # If value of bar is negative: Place label below bar
        if y_value < 0:
            # Invert space to place label below
            space *= -1
            # Vertically align label at top
            va = 'top'

        # Use Y value as label and format number with one decimal place
        label = "{:.0f}".format(y_value)

        # Create annotation
        ax.annotate(
            label,                      # Use `label` as label
            (x_value, y_value),         # Place label at end of the bar
            xytext=(0, space),          # Vertically shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            ha='center',                # Horizontally center label
            va=va)                      # Vertically align label differently for
                                        # positive and negative values.
            

            
def player_rating(name, df):
    rating = []
    for index in range(len(df)):
        if df['white_player'][index] == name:
            rating.append([pd.to_datetime(df['createdAt'][index]).date(), df['speed'][index], df['rating'][index]])
        else:
            rating.append([pd.to_datetime(df['createdAt'][index]).date(), df['speed'][index], df['rating.1'][index]])
    return rating


def clean_rating(df):
    """Cleans the comma from rating column in df"""
    comma = [x[0:-1] if x[-1] ==',' else x for x in df.rating]
    return comma
    

def first_move(dataframe):
    """This function returns a list with the pawn opening. For this classification
    was created four categories of pawn opening: king pawn, queen pawn, english opening and others"""
    first = []
    for item in range(len(dataframe)):
        if dataframe.moves[item][0:2] == 'e4':
            first.append('king pawn')
        elif dataframe.moves[item][0:2] == 'd4':
            first.append('queen pawn')
        elif dataframe.moves[item][0:2] == 'c4':
            first.append('english opening')
        else:
            first.append( 'others')
    return first

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv('game_data.csv')
df.drop('Unnamed: 0', axis = 'columns', inplace=True)
df
# Out:
#       rated   variant      speed       perf                         createdAt  \
# 0      True  standard      blitz      blitz  2022-10-19 01:34:11.197000+00:00
# 1      True  standard      blitz      blitz  2022-10-19 01:20:20.352000+00:00
# 2      True  standard      blitz      blitz  2022-10-19 01:15:39.690000+00:00
# 3      True  standard      blitz      blitz  2022-10-16 16:21:10.320000+00:00
# 4      True  standard      blitz      blitz  2022-10-15 12:52:37.534000+00:00
# ...     ...       ...        ...        ...                               ...
# 1255   True  standard      rapid      rapid  2019-04-15 22:12:18.221000+00:00
# 1256   True  standard      blitz      blitz  2019-04-13 20:54:06.845000+00:00
# 1257   True  standard      rapid      rapid  2019-04-13 20:43:08.889000+00:00
# 1258   True  standard      rapid      rapid  2019-04-12 02:55:21.683000+00:00
# 1259   True  standard  classical  classical  2019-04-09 12:29:18.450000+00:00
#
#          status winner                                              moves  \
# 0        resign  white  e4 d6 Nf3 g6 Bb5+ Bd7 Bxd7+ Nxd7 O-O Bg7 Nc3 c...
# 1        resign  white  e4 e5 Nf3 Nc6 Bb5 d6 c3 Be7 O-O Bg4 d3 Nf6 Re1...
# 2          mate  white  d4 Nf6 Bg5 g6 Bxf6 exf6 e4 Bg7 Nf3 d5 e5 Nc6 B...
# 3     outoftime  white  e4 d5 exd5 Qxd5 Nc3 Qd8 Nf3 Bg4 Be2 e6 d4 Bd6 ...
# 4          mate  white  e4 e5 Nf3 Nc6 Bb5 d6 c3 a6 Ba4 b5 Bc2 Bb7 O-O ...
# ...         ...    ...                                                ...
# 1255    timeout  white  e4 c5 Bc4 e6 e5 d5 Bb5+ Bd7 Bxd7+ Nxd7 c3 Nxe5...
# 1256     resign  black  c4 Nf6 Nc3 g6 g3 Bg7 Bg2 O-O e4 Re8 d3 d6 Nf3 ...
# 1257       mate  white  e4 c6 d4 d5 e5 e6 Nf3 Ne7 Nc3 Nd7 Bd3 f6 O-O N...
# 1258       mate  white  e4 c6 Bc4 d5 exd5 cxd5 Bb3 Bf5 d4 e6 h3 Nc6 c3...
# 1259       draw    NaN  c4 e5 Nc3 Bc5 e3 Nf6 Nge2 Nc6 g3 b6 Bg2 Bb7 d4...
#
#                                                   clock  ECO  \
# 0     {'initial': 180, 'increment': 2, 'totalTime': ...  B00
# 1     {'initial': 180, 'increment': 2, 'totalTime': ...  C62
# 2     {'initial': 180, 'increment': 0, 'totalTime': ...  A45
# 3     {'initial': 300, 'increment': 3, 'totalTime': ...  B01
# 4     {'initial': 300, 'increment': 3, 'totalTime': ...  C74
# ...                                                 ...  ...
# 1255  {'initial': 600, 'increment': 0, 'totalTime': ...  B20
# 1256  {'initial': 180, 'increment': 0, 'totalTime': ...  A16
# 1257  {'initial': 600, 'increment': 0, 'totalTime': ...  B12
# 1258  {'initial': 600, 'increment': 0, 'totalTime': ...  B10
# 1259  {'initial': 900, 'increment': 15, 'totalTime':...  A21
#
#                                            opening_name   white_player rating  \
# 0                                          Pirc Defense   'chestroyer'   1420
# 1                           Ruy Lopez: Steinitz Defense   'chestroyer'   1414
# 2                                     Trompowsky Attack  'chinorafahh'   1410
# 3         Scandinavian Defense: Mieses-Kotroc Variation   'chestroyer'   1415
# 4     Ruy Lopez: Morphy Defense, Modern Steinitz Def...   'chestroyer'   1409
# ...                                                 ...            ...    ...
# 1255                   Sicilian Defense: Bowdler Attack  't-2wadbee-t'   1241
# 1256  English Opening: Anglo-Indian Defense, Queen's...   'chestroyer'   1500
# 1257               Caro-Kann Defense: Advance Variation    'emerson88'   1386
# 1258                Caro-Kann Defense: Hillbilly Attack        'cyote'   1546
# 1259  English Opening: King's English Variation, Rev...   'chestroyer'   1500
#
#       black_player rating.1
# 0         'huurti'     1379
# 1       'albied17'     1386
# 2     'chestroyer'     1421
# 3     'praulo1111'     1396
# 4       'dddeusss'     1392
# ...            ...      ...
# 1255  'chestroyer'     1241
# 1256    'dancab07'     1506
# 1257  'chestroyer'     1346
# 1258  'chestroyer'     1500
# 1259    'mass1962'     1510
#
# [1260 rows x 15 columns]

# %%
df.describe()
# Out:
#        rated   variant  speed   perf                         createdAt status  \
# count   1260      1260   1260   1260                              1260   1260
# unique     2         2      5      5                              1260      6
# top     True  standard  blitz  blitz  2022-10-19 01:34:11.197000+00:00   mate
# freq    1251      1254    592    592                                 1    515
#
#        winner                                              moves  \
# count    1213                                               1260
# unique      2                                               1260
# top     white  e4 d6 Nf3 g6 Bb5+ Bd7 Bxd7+ Nxd7 O-O Bg7 Nc3 c...
# freq      662                                                  1
#
#                                                     clock   ECO  \
# count                                                1258  1260
# unique                                                 15   150
# top     {'initial': 300, 'increment': 0, 'totalTime': ...   B20
# freq                                                  326    80
#
#             opening_name  white_player rating  black_player rating.1
# count               1260          1260   1260          1260     1260
# unique               334           626    613           622      602
# top     Sicilian Defense  'chestroyer'   1500  'chestroyer'     1500
# freq                  57           629     15           631        8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rated         1260 non-null   bool
#  1   variant       1260 non-null   object
#  2   speed         1260 non-null   object
#  3   perf          1260 non-null   object
#  4   createdAt     1260 non-null   object
#  5   status        1260 non-null   object
#  6   winner        1213 non-null   object
#  7   moves         1260 non-null   object
#  8   clock         1258 non-null   object
#  9   ECO           1260 non-null   object
#  10  opening_name  1260 non-null   object
#  11  white_player  1260 non-null   object
#  12  rating        1260 non-null   object
#  13  black_player  1260 non-null   object
#  14  rating.1      1260 non-null   object
# dtypes: bool(1), object(14)
# memory usage: 139.2+ KB

# %%
df['pawn_opening'] = first_move(df)
df
# Out:
#       rated   variant      speed       perf                         createdAt  \
# 0      True  standard      blitz      blitz  2022-10-19 01:34:11.197000+00:00
# 1      True  standard      blitz      blitz  2022-10-19 01:20:20.352000+00:00
# 2      True  standard      blitz      blitz  2022-10-19 01:15:39.690000+00:00
# 3      True  standard      blitz      blitz  2022-10-16 16:21:10.320000+00:00
# 4      True  standard      blitz      blitz  2022-10-15 12:52:37.534000+00:00
# ...     ...       ...        ...        ...                               ...
# 1255   True  standard      rapid      rapid  2019-04-15 22:12:18.221000+00:00
# 1256   True  standard      blitz      blitz  2019-04-13 20:54:06.845000+00:00
# 1257   True  standard      rapid      rapid  2019-04-13 20:43:08.889000+00:00
# 1258   True  standard      rapid      rapid  2019-04-12 02:55:21.683000+00:00
# 1259   True  standard  classical  classical  2019-04-09 12:29:18.450000+00:00
#
#          status winner                                              moves  \
# 0        resign  white  e4 d6 Nf3 g6 Bb5+ Bd7 Bxd7+ Nxd7 O-O Bg7 Nc3 c...
# 1        resign  white  e4 e5 Nf3 Nc6 Bb5 d6 c3 Be7 O-O Bg4 d3 Nf6 Re1...
# 2          mate  white  d4 Nf6 Bg5 g6 Bxf6 exf6 e4 Bg7 Nf3 d5 e5 Nc6 B...
# 3     outoftime  white  e4 d5 exd5 Qxd5 Nc3 Qd8 Nf3 Bg4 Be2 e6 d4 Bd6 ...
# 4          mate  white  e4 e5 Nf3 Nc6 Bb5 d6 c3 a6 Ba4 b5 Bc2 Bb7 O-O ...
# ...         ...    ...                                                ...
# 1255    timeout  white  e4 c5 Bc4 e6 e5 d5 Bb5+ Bd7 Bxd7+ Nxd7 c3 Nxe5...
# 1256     resign  black  c4 Nf6 Nc3 g6 g3 Bg7 Bg2 O-O e4 Re8 d3 d6 Nf3 ...
# 1257       mate  white  e4 c6 d4 d5 e5 e6 Nf3 Ne7 Nc3 Nd7 Bd3 f6 O-O N...
# 1258       mate  white  e4 c6 Bc4 d5 exd5 cxd5 Bb3 Bf5 d4 e6 h3 Nc6 c3...
# 1259       draw    NaN  c4 e5 Nc3 Bc5 e3 Nf6 Nge2 Nc6 g3 b6 Bg2 Bb7 d4...
#
#                                                   clock  ECO  \
# 0     {'initial': 180, 'increment': 2, 'totalTime': ...  B00
# 1     {'initial': 180, 'increment': 2, 'totalTime': ...  C62
# 2     {'initial': 180, 'increment': 0, 'totalTime': ...  A45
# 3     {'initial': 300, 'increment': 3, 'totalTime': ...  B01
# 4     {'initial': 300, 'increment': 3, 'totalTime': ...  C74
# ...                                                 ...  ...
# 1255  {'initial': 600, 'increment': 0, 'totalTime': ...  B20
# 1256  {'initial': 180, 'increment': 0, 'totalTime': ...  A16
# 1257  {'initial': 600, 'increment': 0, 'totalTime': ...  B12
# 1258  {'initial': 600, 'increment': 0, 'totalTime': ...  B10
# 1259  {'initial': 900, 'increment': 15, 'totalTime':...  A21
#
#                                            opening_name   white_player rating  \
# 0                                          Pirc Defense   'chestroyer'   1420
# 1                           Ruy Lopez: Steinitz Defense   'chestroyer'   1414
# 2                                     Trompowsky Attack  'chinorafahh'   1410
# 3         Scandinavian Defense: Mieses-Kotroc Variation   'chestroyer'   1415
# 4     Ruy Lopez: Morphy Defense, Modern Steinitz Def...   'chestroyer'   1409
# ...                                                 ...            ...    ...
# 1255                   Sicilian Defense: Bowdler Attack  't-2wadbee-t'   1241
# 1256  English Opening: Anglo-Indian Defense, Queen's...   'chestroyer'   1500
# 1257               Caro-Kann Defense: Advance Variation    'emerson88'   1386
# 1258                Caro-Kann Defense: Hillbilly Attack        'cyote'   1546
# 1259  English Opening: King's English Variation, Rev...   'chestroyer'   1500
#
#       black_player rating.1     pawn_opening
# 0         'huurti'     1379        king pawn
# 1       'albied17'     1386        king pawn
# 2     'chestroyer'     1421       queen pawn
# 3     'praulo1111'     1396        king pawn
# 4       'dddeusss'     1392        king pawn
# ...            ...      ...              ...
# 1255  'chestroyer'     1241        king pawn
# 1256    'dancab07'     1506  english opening
# 1257  'chestroyer'     1346        king pawn
# 1258  'chestroyer'     1500        king pawn
# 1259    'mass1962'     1510  english opening
#
# [1260 rows x 16 columns]

# %%
player_name = "'chestroyer'"

# %% [markdown]
# ## Statistical Distributions

# %%
df.columns
columns_of_interest = ['rated', 'speed', 'status', 'winner', 'pawn_opening', 'ECO', 'opening_name', 'moves']
for column in columns_of_interest:
    print('-'*120)
    print(f'{column} analysis:\n{df[column].value_counts()}')
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# rated analysis:
# True     1251
# False       9
# Name: rated, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# speed analysis:
# blitz             592
# classical         321
# rapid             215
# bullet            130
# correspondence      2
# Name: speed, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# status analysis:
# mate         515
# resign       383
# outoftime    270
# timeout       46
# draw          24
# stalemate     22
# Name: status, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# winner analysis:
# white    662
# black    551
# Name: winner, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# pawn_opening analysis:
# king pawn          619
# queen pawn         425
# english opening    123
# others              93
# Name: pawn_opening, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# ECO analysis:
# B20    80
# C00    71
# A45    61
# B50    56
# A40    49
#        ..
# C26     1
# E87     1
# A52     1
# D43     1
# C43     1
# Name: ECO, Length: 150, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# opening_name analysis:
# Sicilian Defense                                                       57
# Indian Defense                                                         47
# Sicilian Defense: Bowdler Attack                                       36
# Caro-Kann Defense                                                      32
# English Opening: King's English Variation                              28
#                                                                        ..
# Queen's Gambit Declined: Semi-Tarrasch Defense, Pillsbury Variation     1
# Englund Gambit Complex: Felbecker Gambit                                1
# Ruy Lopez: Bird Variation                                               1
# King's Pawn Game: Busch-Gass Gambit                                     1
# Zukertort Opening: Ross Gambit                                          1
# Name: opening_name, Length: 334, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# moves analysis:
# e4 d6 Nf3 g6 Bb5+ Bd7 Bxd7+ Nxd7 O-O Bg7 Nc3 c5 b3 Qc7 Bb2 Ngf6 d4 cxd4 Nxd4 Nxe4 Ndb5 Qc6 Nd4 Nxc3 Bxc3 Qxc3 Nb5 Qc5 a4 Bxa1 Qxa1 a6 Qxh8+ Nf8 Nxd6+ exd6 Re1+ Kd7 Qf6 Ne6 Qxf7+ Kc6 Qxe6 Qxc2 Qe3 Kd7 Rc1 Qb2 Qh3+ Kd8 Qh4+ Kd7 Qxh7+ Ke6 Re1+ Kd5 Qf7+ Kc6 Qf3+ d5 Re6+ Kc5 Qe3+ d4 Qe5+ Kb4 Rb6+ Kc3 Qc5+ Kd2 Qg5+ Kc3 g3 Re8 Qxg6 Re1+ Kg2 Qc1 Rxb7 Rg1+ Kh3 Qd2 Rc7+ Kxb3 Qb6+ Kxa4 Rc4+ Ka3 Qxa6+ Kb2 Qb5+ Ka1 Ra4+ Qa2 Rxa2+ Kxa2 Qe2+ Kb3 Qd3+ Kb4 Qxd4+ Kb3 f4 Rb1 f5 Rf1 Qf4    1
# d4 Nf6 Bf4 d6 e3 Bf5 Nd2 g6 Ngf3 Bg7 Nc4 c5 Bd3 Bg4 h3 Bxf3 Qxf3 cxd4 exd4 Nbd7 O-O b5 Nd2 a6 Rfe1 O-O Re2 Re8 Rae1 Qc7 Ne4 e5 Nxf6+ Bxf6 Be4 Rac8 Bh6 Qc4 c3 exd4 h4 dxc3 h5 cxb2 Rxb2 Bxb2 hxg6 hxg6 Bd3 Qc3 Qxf7+ Kxf7                                                                                                                                                                                                                                                                  1
# e4 c5 Nf3 e6 Nc3 Nc6 Bc4 Be7 d4 cxd4 Nxd4 Qb6 Nxc6 Qxc6 O-O Nf6 e5 Ne4 Qf3 d5 Nxe4 Qxc4 Nd2 Qc6 c4 O-O cxd5 Qxd5 Qxd5 exd5 Nf3 Be6 Bg5 f6 Bf4 g5 exf6 Rxf6 Bxg5 Rf7 Bxe7 Rxe7 Ng5 Bf5 Rad1 Rd8 Rfe1 Rxe1+ Rxe1 d4 Re7 h6 Nf3 d3 Nd2 Kf8 Rxb7 Bc8 Rxa7 Rd5 Kf1 Re5 Ra3 Bf5 f4 Re2 Ra5 Bg4 h3 Rxd2 hxg4 Rxb2 Ke1 d2+ Kd1 Kg7 a4 Kg6 Rf5 h5 gxh5+ Kg7 h6+                                                                                                                                     1
# d4 d5 c4 dxc4 e4 Nc6 Nc3 Nxd4 Bxc4 Nf6 Be3 Bg4 f3 Bh5 g4 Bg6 Nge2 Nxf3+ Kf2 Qxd1 Raxd1 Ne5 Bb5+ c6 Ba4 b5 Bc2 Nexg4+ Kg3 Nxe3 Rd2 Nxc2 Rxc2 b4 Na4 Bxe4 Rcc1 Bxh1 Rxh1 Rd8 Nc5 Nh5+ Kh4 g6 Nb7 Rd2 Re1 Rxb2 Nd4 Rxh2+ Kg4 f5+ Kf3 Rh3+ Kg2 Rg3+ Kf2 Bh6 Nxc6 e6 Rxe6+ Kd7 Nc5+ Kc7 Nxb4 Rf8 Rc6+ Kb8 Nba6+ Ka8 Nc7+                                                                                                                                                                        1
# e4 c5 Nf3 e6 a3 Nc6 Bc4 Be7 O-O Nf6 Re1 d5 exd5 exd5 Ba2 O-O Ng5 h6 d3 hxg5 Bxg5 Be6 h4 Bg4 Qd2 Ne5 Rxe5 Re8 Nc3 Bd6 Rxe8+ Qxe8 Bxd5 Qe5 Bxb7 Qh2+ Kf1 Qh1#                                                                                                                                                                                                                                                                                                                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ..
# e4 c6 Nc3 d5 e5 Bf5 g4 Bg6 d4 e6 h4 h6 h5 Bh7 Bd2 Qb6 Nf3 Nd7 Qe2 c5 dxc5 Bxc5 O-O-O Ne7 Bg2 Nc6 Nh4 Nd4 Qf1 Nxc2 Bxd5 Ba3 Na4 Bxb2+ Nxb2 Rc8 Nc4 Qc5 Nd6+ Ke7 Nhf5+ exf5 gxf5 Ne3+ Kb1 Qc2+ Ka1 Rc5 f6+ gxf6 exf6+ Nxf6 Bxe3 Rxd5 Rxd5 Nxd5 Qb5 Nc3 Qxb7+ Kxd6 Qa6+ Ke7 Bc5+ Kd7 Qd6+ Kc8 Qa6+ Kc7 Qa5+ Kc6 Qb4 Qxa2#                                                                                                                                                                     1
# d4 d5 c4 e6 Nf3 Nf6 Nc3 Nbd7 Bg5 Be7 Bxf6 Bxf6 e3 c5 Nb5 cxd4 Nfxd4 Ne5 b3 dxc4 bxc4 Nc6 Bd3 a6 Nc3 Nxd4 exd4 Qxd4 Rc1 O-O Ne2 Qg4 O-O Bd7 Bxh7+ Kxh7 f3 Qg6 Qxd7 Rad8 Qxb7 Bd4+ Nxd4 Rxd4 Qb6 Qd3 Qxa6 Qe3+ Kh1 Rfd8 c5 Qe5 c6 Qc7 Qb7 Rc8 Qxc7 Rxc7 Rc5 Rd5 Rxd5 exd5 Rd1 Rxc6 Rxd5 Ra6 Rd2 f5 Kg1 g5 Kf2 Kh6 Kg3 f4+ Kg4 Kg6 h4 gxh4 Kxh4 Kf5 g4+ Kg6 g5 Kf5 Kh5 Ra3 Rf2 Ra6 Rg2 Rg6 a4 Rg7 Kh6 Ra7 Ra2 Re7 g6 Re6 Kh5 Rxg6 Rg2 Rxg2                                                    1
# d4 d5 c4 e6 Nc3 Nf6 e3 b6 Qf3 Ba6 b3 Bb7 Nge2 Nbd7 Ng3 Rb8 Qd1 dxc4 Bxc4 Bb4 Bd2 O-O O-O c5 Qc2 cxd4 exd4 e5 d5 Nc5 Rfe1 Re8 Nge4 Ncxe4 Nxe4 Nxe4 Rxe4 Bxd2 Qxd2 Bc6 Rd1 Bb7 Rg4 Qf6 d6 e4 Rf4 Qg5                                                                                                                                                                                                                                                                                         1
# d4 Nf6 c4 d6 Nc3 g6 Nf3 Bg7 Bf4 Nbd7 e4 Nh5 Be3 O-O Be2 Re8 Nd2 Nhf6 Nf3 e5 dxe5 Nxe5 Nxe5 dxe5 Qxd8 Rxd8 O-O Bg4 Bxg4 Nxg4 Bc5 b6 Ba3 f5 f3 Nf6 Nd5 Nxd5 cxd5 fxe4 fxe4 Rac8 Rac1 Rd7 Rfd1 Rcd8 Be7 Rxe7                                                                                                                                                                                                                                                                                  1
# c4 e5 Nc3 Bc5 e3 Nf6 Nge2 Nc6 g3 b6 Bg2 Bb7 d4 Bb4 Bd2 O-O O-O Re8 a3 Bd6 Ne4 Be7 Qb3 exd4 exd4 Ng4 c5 Nb8 cxb6 axb6 Rac1 d5 Ng5 Bxg5 Bxg5 Qxg5 Rxc7 Ba6 Qxd5 Qxd5 Bxd5 Bxe2 Re1 Na6 Bxa8 Nxc7 Bc6 Re7 f3 Nf6 g4 Ncd5 g5 Bxf3 Rxe7 Nxe7 Bxf3 Nfd5 h4 Nf4 b4 f5 a4 Nfd5 a5 bxa5 bxa5 Kf8 h5 Ke8 a6 Nc7 a7 f4 g6 hxg6 hxg6 Nxg6 Bc6+ Kd8 d5 Ne5 d6 Nxc6 dxc7+ Kxc7 a8=Q f3 Kf2 g5 Qg8 g4 Qxg4 Kb7 Kxf3 Ne5+ Kf4 Nxg4                                                                         1
# Name: moves, Length: 1260, dtype: int64

# %%
for column in columns_of_interest[0:5]:
    fig, ax = plt.subplots(figsize=(10, 8))
    ax = sns.barplot(x= df[column].value_counts().index, y=df[column].value_counts().values, palette='YlGnBu', ax=ax)
    plt.title(f'{column} Barplot')
    add_value_labels(ax)

# %% [markdown]
# # Gameplay Style

# %% [markdown]
# ## Playing as White

# %%
playing_white = df.loc[df['white_player'] == player_name, :]
playing_white
# Out:
#       rated   variant      speed       perf                         createdAt  \
# 0      True  standard      blitz      blitz  2022-10-19 01:34:11.197000+00:00
# 1      True  standard      blitz      blitz  2022-10-19 01:20:20.352000+00:00
# 3      True  standard      blitz      blitz  2022-10-16 16:21:10.320000+00:00
# 4      True  standard      blitz      blitz  2022-10-15 12:52:37.534000+00:00
# 6      True  standard      blitz      blitz  2022-10-15 02:26:53.015000+00:00
# ...     ...       ...        ...        ...                               ...
# 1249   True  standard     bullet     bullet  2019-04-24 22:38:23.732000+00:00
# 1252   True  standard  classical  classical  2019-04-24 13:23:49.627000+00:00
# 1254   True  standard      rapid      rapid  2019-04-16 14:24:02.081000+00:00
# 1256   True  standard      blitz      blitz  2019-04-13 20:54:06.845000+00:00
# 1259   True  standard  classical  classical  2019-04-09 12:29:18.450000+00:00
#
#          status winner                                              moves  \
# 0        resign  white  e4 d6 Nf3 g6 Bb5+ Bd7 Bxd7+ Nxd7 O-O Bg7 Nc3 c...
# 1        resign  white  e4 e5 Nf3 Nc6 Bb5 d6 c3 Be7 O-O Bg4 d3 Nf6 Re1...
# 3     outoftime  white  e4 d5 exd5 Qxd5 Nc3 Qd8 Nf3 Bg4 Be2 e6 d4 Bd6 ...
# 4          mate  white  e4 e5 Nf3 Nc6 Bb5 d6 c3 a6 Ba4 b5 Bc2 Bb7 O-O ...
# 6        resign  black  d4 d5 c4 e6 Nc3 Nf6 Bf4 c5 e3 Nc6 Bd3 cxd4 exd...
# ...         ...    ...                                                ...
# 1249     resign  black  Nf3 Nf6 e4 g6 Bc4 Bg7 d4 O-O Bg5 d6 O-O b6 e5 ...
# 1252     resign  black  Nf3 c5 e4 d6 Bb5+ Bd7 a4 Nc6 O-O g6 d4 cxd4 Nx...
# 1254    timeout  white  Nf3 e5 d3 d6 e4 Nf6 Nc3 Be7 h3 O-O Bg5 a5 d4 e...
# 1256     resign  black  c4 Nf6 Nc3 g6 g3 Bg7 Bg2 O-O e4 Re8 d3 d6 Nf3 ...
# 1259       draw    NaN  c4 e5 Nc3 Bc5 e3 Nf6 Nge2 Nc6 g3 b6 Bg2 Bb7 d4...
#
#                                                   clock  ECO  \
# 0     {'initial': 180, 'increment': 2, 'totalTime': ...  B00
# 1     {'initial': 180, 'increment': 2, 'totalTime': ...  C62
# 3     {'initial': 300, 'increment': 3, 'totalTime': ...  B01
# 4     {'initial': 300, 'increment': 3, 'totalTime': ...  C74
# 6     {'initial': 180, 'increment': 0, 'totalTime': ...  D35
# ...                                                 ...  ...
# 1249   {'initial': 60, 'increment': 0, 'totalTime': 60}  A05
# 1252  {'initial': 900, 'increment': 15, 'totalTime':...  B52
# 1254  {'initial': 600, 'increment': 0, 'totalTime': ...  A04
# 1256  {'initial': 180, 'increment': 0, 'totalTime': ...  A16
# 1259  {'initial': 900, 'increment': 15, 'totalTime':...  A21
#
#                                            opening_name  white_player rating  \
# 0                                          Pirc Defense  'chestroyer'   1420
# 1                           Ruy Lopez: Steinitz Defense  'chestroyer'   1414
# 3         Scandinavian Defense: Mieses-Kotroc Variation  'chestroyer'   1415
# 4     Ruy Lopez: Morphy Defense, Modern Steinitz Def...  'chestroyer'   1409
# 6              Queen's Gambit Declined: Harrwitz Attack  'chestroyer'   1420
# ...                                                 ...           ...    ...
# 1249                Zukertort Opening: Lemberger Gambit  'chestroyer'   1500
# 1252          Sicilian Defense: Canal Attack, Main Line  'chestroyer'   1406
# 1254                     Zukertort Opening: Ross Gambit  'chestroyer'   1152
# 1256  English Opening: Anglo-Indian Defense, Queen's...  'chestroyer'   1500
# 1259  English Opening: King's English Variation, Rev...  'chestroyer'   1500
#
#         black_player rating.1     pawn_opening
# 0           'huurti'     1379        king pawn
# 1         'albied17'     1386        king pawn
# 3       'praulo1111'     1396        king pawn
# 4         'dddeusss'     1392        king pawn
# 6          'schrani'     1459       queen pawn
# ...              ...      ...              ...
# 1249  'lordfarsomin'     1497           others
# 1252   'mateifaibis'     1424           others
# 1254       'ahmaadd'     1060           others
# 1256      'dancab07'     1506  english opening
# 1259      'mass1962'     1510  english opening
#
# [629 rows x 16 columns]

# %% [markdown]
# ### Winning rate playing as white

# %%
print(playing_white.winner.value_counts())
print('-'*100)
print(playing_white.winner.value_counts(normalize=True)*100)
# Out:
# white    354
# black    253
# Name: winner, dtype: int64
# ----------------------------------------------------------------------------------------------------
# white    58.319605
# black    41.680395
# Name: winner, dtype: float64

# %% [markdown]
# ### Most played openings (ECO and name)

# %%
playing_white.ECO.value_counts()
# Out:
# A40    48
# D20    38
# D00    28
# D06    28
# A20    26
#        ..
# D43     1
# C67     1
# E90     1
# A85     1
# B52     1
# Name: ECO, Length: 116, dtype: int64

# %%
playing_white.opening_name.value_counts()
# Out:
# English Opening: King's English Variation                                            26
# Queen's Pawn Game: Accelerated London System                                         24
# Queen's Gambit Declined: Marshall Defense                                            22
# Philidor Defense                                                                     21
# Horwitz Defense                                                                      18
#                                                                                      ..
# English Opening: King's English Variation, Two Knights Variation, Reversed Dragon     1
# Queen's Pawn Game: London System                                                      1
# Queen's Gambit Accepted: Central Variation, McDonnell Defense                         1
# Scotch Game: Scotch Gambit, Dubois Réti Defense                                       1
# Zukertort Opening: Ross Gambit                                                        1
# Name: opening_name, Length: 223, dtype: int64

# %% [markdown]
# ### Most succesful openings (that resulted in a win)

# %%
playing_white.loc[playing_white.winner=='white', 'ECO'].value_counts()
# Out:
# A40    33
# D20    19
# C41    17
# D06    17
# A20    17
#        ..
# B13     1
# C24     1
# B29     1
# E61     1
# D94     1
# Name: ECO, Length: 85, dtype: int64

# %%
playing_white.loc[playing_white.winner=='white', 'opening_name'].value_counts()
# Out:
# English Opening: King's English Variation       17
# Philidor Defense                                16
# Queen's Gambit Declined: Marshall Defense       12
# Queen's Pawn Game: Accelerated London System    12
# Horwitz Defense                                 10
#                                                 ..
# Ruy Lopez: Pollock Defense                       1
# French Defense                                   1
# French Defense: Perseus Gambit                   1
# Indian Defense                                   1
# Zukertort Opening: Ross Gambit                   1
# Name: opening_name, Length: 158, dtype: int64

# %%
for column in columns_of_interest[0:4]:
    fig, ax = plt.subplots(figsize=(10, 8))
    ax = sns.barplot(x= playing_white[column].value_counts().index, y=playing_white[column].value_counts().values, palette='YlGnBu', ax=ax)
    plt.title(f'{column} Barplot')
    add_value_labels(ax)

# %%
fig, ax = plt.subplots(figsize=(25, 13))
ax = sns.barplot(x=playing_white['opening_name'].value_counts().values[0:20], 
                 y=playing_white['opening_name'].value_counts().index[0:20],
                 palette='mako')

# %% [markdown]
# # Playing as Black

# %%
playing_black = df.loc[df['black_player'] == player_name, :]
playing_black
# Out:
#       rated   variant      speed       perf                         createdAt  \
# 2      True  standard      blitz      blitz  2022-10-19 01:15:39.690000+00:00
# 5      True  standard      blitz      blitz  2022-10-15 12:33:21.967000+00:00
# 8      True  standard      blitz      blitz  2022-10-15 00:02:34.566000+00:00
# 9      True  standard      blitz      blitz  2022-10-11 23:03:11.816000+00:00
# 11     True  standard      rapid      rapid  2022-10-05 16:19:50.863000+00:00
# ...     ...       ...        ...        ...                               ...
# 1251   True  standard  classical  classical  2019-04-24 13:33:17.318000+00:00
# 1253   True  standard  classical  classical  2019-04-18 11:48:37.237000+00:00
# 1255   True  standard      rapid      rapid  2019-04-15 22:12:18.221000+00:00
# 1257   True  standard      rapid      rapid  2019-04-13 20:43:08.889000+00:00
# 1258   True  standard      rapid      rapid  2019-04-12 02:55:21.683000+00:00
#
#          status winner                                              moves  \
# 2          mate  white  d4 Nf6 Bg5 g6 Bxf6 exf6 e4 Bg7 Nf3 d5 e5 Nc6 B...
# 5          mate  white  e4 c5 Bc4 e6 Nf3 Nc6 d3 d5 exd5 exd5 Bb3 Nf6 B...
# 8     outoftime  black  c4 Nf6 e3 g6 Nc3 d5 d4 e6 Be2 Bg7 Nf3 Nbd7 O-O...
# 9          mate  white  e4 c5 Nf3 e6 Nc3 Nc6 Be2 Be7 d4 cxd4 Nxd4 Nxd4...
# 11       resign  white  e4 c5 Nf3 e6 Nc3 Nc6 a3 a6 Bc4 b5 Ba2 Bb7 d3 B...
# ...         ...    ...                                                ...
# 1251       mate  white  e4 c6 Nf3 d5 e5 e6 g3 Bc5 d4 Bb6 Bg2 Ne7 O-O O...
# 1253       mate  white  e4 c5 Nc3 e6 Nf3 Nc6 d4 a6 d5 Nd4 Nxd4 cxd4 Qx...
# 1255    timeout  white  e4 c5 Bc4 e6 e5 d5 Bb5+ Bd7 Bxd7+ Nxd7 c3 Nxe5...
# 1257       mate  white  e4 c6 d4 d5 e5 e6 Nf3 Ne7 Nc3 Nd7 Bd3 f6 O-O N...
# 1258       mate  white  e4 c6 Bc4 d5 exd5 cxd5 Bb3 Bf5 d4 e6 h3 Nc6 c3...
#
#                                                   clock  ECO  \
# 2     {'initial': 180, 'increment': 0, 'totalTime': ...  A45
# 5     {'initial': 300, 'increment': 3, 'totalTime': ...  B20
# 8     {'initial': 300, 'increment': 0, 'totalTime': ...  A15
# 9     {'initial': 300, 'increment': 0, 'totalTime': ...  B40
# 11    {'initial': 600, 'increment': 5, 'totalTime': ...  B40
# ...                                                 ...  ...
# 1251  {'initial': 900, 'increment': 15, 'totalTime':...  B10
# 1253  {'initial': 900, 'increment': 15, 'totalTime':...  B23
# 1255  {'initial': 600, 'increment': 0, 'totalTime': ...  B20
# 1257  {'initial': 600, 'increment': 0, 'totalTime': ...  B12
# 1258  {'initial': 600, 'increment': 0, 'totalTime': ...  B10
#
#                                opening_name   white_player rating  \
# 2                         Trompowsky Attack  'chinorafahh'   1410
# 5          Sicilian Defense: Bowdler Attack        'zyody'   1458
# 8     English Opening: Anglo-Indian Defense      'nixsone'   1453
# 9        Sicilian Defense: French Variation    'smzlsmile'   1440
# 11       Sicilian Defense: French Variation         'sqld'   1703
# ...                                     ...            ...    ...
# 1251                      Caro-Kann Defense  'mateifaibis'   1433
# 1253               Sicilian Defense: Closed   'ma_diamond'   1500
# 1255       Sicilian Defense: Bowdler Attack  't-2wadbee-t'   1241
# 1257   Caro-Kann Defense: Advance Variation    'emerson88'   1386
# 1258    Caro-Kann Defense: Hillbilly Attack        'cyote'   1546
#
#       black_player rating.1     pawn_opening
# 2     'chestroyer'     1421       queen pawn
# 5     'chestroyer'     1414        king pawn
# 8     'chestroyer'     1419  english opening
# 9     'chestroyer'     1425        king pawn
# 11    'chestroyer'     1644        king pawn
# ...            ...      ...              ...
# 1251  'chestroyer'     1309        king pawn
# 1253  'chestroyer'     1504        king pawn
# 1255  'chestroyer'     1241        king pawn
# 1257  'chestroyer'     1346        king pawn
# 1258  'chestroyer'     1500        king pawn
#
# [631 rows x 16 columns]

# %% [markdown]
# ### Winning rate as black

# %%
print(playing_black['winner'].value_counts())
print('-'*100)
print(playing_black['winner'].value_counts(normalize=True)*100)
# Out:
# white    308
# black    298
# Name: winner, dtype: int64
# ----------------------------------------------------------------------------------------------------
# white    50.825083
# black    49.174917
# Name: winner, dtype: float64

# %%
for column in columns_of_interest[0:4]:
    fig, ax = plt.subplots(figsize=(10, 8))
    ax = sns.barplot(x= playing_black[column].value_counts().index, y=playing_black[column].value_counts().values, palette='YlGnBu', ax=ax)
    plt.title(f'{column} Barplot')
    add_value_labels(ax)

# %% [markdown]
# ### Most played openings as black

# %%
playing_black.ECO.value_counts()
# Out:
# B20    75
# C00    58
# A45    56
# B50    48
# B10    34
#        ..
# D50     1
# E65     1
# E11     1
# A43     1
# C41     1
# Name: ECO, Length: 90, dtype: int64

# %%
playing_black.opening_name.value_counts()[0:15]
# Out:
# Sicilian Defense                                         50
# Indian Defense                                           43
# Sicilian Defense: Bowdler Attack                         33
# Sicilian Defense: Modern Variations                      27
# Caro-Kann Defense                                        25
# French Defense: Knight Variation                         24
# Sicilian Defense: Smith-Morra Gambit                     22
# Sicilian Defense: Closed                                 21
# French Defense                                           14
# Sicilian Defense: French Variation                       12
# East Indian Defense                                      11
# French Defense: Advance Variation                        11
# French Defense: Advance Variation, Nimzowitsch System    11
# London System                                            10
# Van't Kruijs Opening                                     10
# Name: opening_name, dtype: int64

# %%
strip_opening_b = [str(x).split(':')[0] for x in playing_black.opening_name.value_counts().index]
count_openings_b = [[x, strip_opening_b.count(str(x))] for x in strip_opening_b]
count_openings_unique_b = []

for l in count_openings_b:
    if l not in count_openings_unique_b:
        count_openings_unique_b.append(l)
count_openings_unique_b
# Out:
# [['Sicilian Defense', 37],
#  ['Indian Defense', 9],
#  ['Caro-Kann Defense', 15],
#  ['French Defense', 17],
#  ['East Indian Defense', 1],
#  ['London System', 1],
#  ["Van't Kruijs Opening", 1],
#  ['Hungarian Opening', 2],
#  ["Queen's Pawn Game", 9],
#  ["King's Indian Defense", 12],
#  ["King's Indian Attack", 1],
#  ['Trompowsky Attack', 2],
#  ['Nimzo-Larsen Attack', 2],
#  ['Grünfeld Defense', 7],
#  ['Old Indian Defense', 1],
#  ['Polish Opening', 2],
#  ['Neo-Grünfeld Defense', 3],
#  ['None', 1],
#  ['English Opening', 9],
#  ['Van Geet Opening', 2],
#  ['Nimzo-Indian Defense', 1],
#  ['Pirc Defense', 1],
#  ['Paleface Attack', 1],
#  ["Bishop's Opening", 1],
#  ['Russian Game', 4],
#  ['Philidor Defense', 1],
#  ['Modern Defense', 1],
#  ["King's Pawn Game", 1],
#  ['Amar Opening', 1],
#  ['Bird Opening', 1],
#  ['Torre Attack', 2],
#  ["Queen's Gambit Declined", 4],
#  ['Zukertort Opening', 3],
#  ['Sodium Attack', 1],
#  ['Vienna Game', 1],
#  ["King's Gambit Declined", 1],
#  ['Four Knights Game', 2],
#  ["King's Gambit Accepted", 1],
#  ['Scotch Game', 1],
#  ['Englund Gambit Declined', 1],
#  ['Benoni Defense', 1],
#  ['Bogo-Indian Defense', 1],
#  ["Queen's Pawn, Mengarini Attack", 1],
#  ['Yusupov-Rubinstein System', 1]]

# %%
plot_df = pd.DataFrame(count_openings_unique_b, columns=['opening', 'times_played'])
plot_df = plot_df.sort_values(by=['times_played'], ascending=False)

fig, ax = plt.subplots(figsize=(25, 13))
ax = sns.barplot(x=plot_df.times_played, 
                 y=plot_df.opening,
                 palette='mako')

# %%
fig, ax = plt.subplots(figsize=(25, 13))
ax = sns.barplot(x=playing_black['opening_name'].value_counts().values[0:20], 
                 y=playing_black['opening_name'].value_counts().index[0:20],
                 palette='mako')

# %% [markdown]
# ### Most succesful openings as black

# %%
playing_black.loc[playing_black['winner']=='black', :].ECO.value_counts()[0:15]
# Out:
# B20    36
# A45    29
# C00    28
# B10    20
# B50    18
# B21    15
# A00    13
# C02    13
# A48    13
# B23    13
# B40    11
# B12     9
# B22     4
# D00     4
# E60     4
# Name: ECO, dtype: int64

# %%
playing_black.loc[playing_black['winner']=='black', :].opening_name.value_counts()[0:15]
# Out:
# Indian Defense                                           22
# Sicilian Defense                                         18
# Sicilian Defense: Bowdler Attack                         17
# Caro-Kann Defense                                        13
# Sicilian Defense: Closed                                 13
# Sicilian Defense: Modern Variations                      13
# Sicilian Defense: Smith-Morra Gambit                     12
# French Defense: Knight Variation                         10
# French Defense                                            8
# French Defense: Advance Variation, Nimzowitsch System     7
# Caro-Kann Defense: Hillbilly Attack                       7
# London System                                             6
# Sicilian Defense: French Variation                        6
# East Indian Defense                                       5
# Hungarian Opening                                         4
# Name: opening_name, dtype: int64

# %%
strip_opening_b2 = [str(x).split(':')[0] for x in playing_black.loc[playing_black['winner']=='black', :].opening_name.value_counts().index]
count_openings_b2 = [[x, strip_opening_b2.count(str(x))] for x in strip_opening_b2]
count_openings_unique_b2 = []

for l in count_openings_b2:
    if l not in count_openings_unique_b2:
        count_openings_unique_b2.append(l)
count_openings_unique_b2
# Out:
# [['Indian Defense', 6],
#  ['Sicilian Defense', 24],
#  ['Caro-Kann Defense', 9],
#  ['French Defense', 13],
#  ['London System', 1],
#  ['East Indian Defense', 1],
#  ['Hungarian Opening', 1],
#  ['Old Indian Defense', 1],
#  ["Queen's Pawn Game", 6],
#  ["Van't Kruijs Opening", 1],
#  ['Nimzo-Larsen Attack', 2],
#  ['Grünfeld Defense', 3],
#  ['Trompowsky Attack', 1],
#  ['Paleface Attack', 1],
#  ["King's Indian Defense", 10],
#  ['Bogo-Indian Defense', 1],
#  ["King's Indian Attack", 1],
#  ['English Opening', 5],
#  ['Neo-Grünfeld Defense', 2],
#  ['Sodium Attack', 1],
#  ['Torre Attack', 2],
#  ['Polish Opening', 2],
#  ['Amar Opening', 1],
#  ['Bird Opening', 1],
#  ['Nimzo-Indian Defense', 1],
#  ['Zukertort Opening', 2],
#  ['None', 1],
#  ['Englund Gambit Declined', 1],
#  ['Russian Game', 3],
#  ['Van Geet Opening', 2],
#  ["Queen's Pawn, Mengarini Attack", 1],
#  ["Queen's Gambit Declined", 2],
#  ['Yusupov-Rubinstein System', 1],
#  ["King's Pawn Game", 1]]

# %%
plot_df = pd.DataFrame(count_openings_unique_b2, columns=['opening', 'times_played'])
plot_df = plot_df.sort_values(by=['times_played'], ascending=False)

fig, ax = plt.subplots(figsize=(25, 13))
ax = sns.barplot(x=plot_df.times_played, 
                 y=plot_df.opening,
                 palette='mako')

# %%
fig, ax = plt.subplots(figsize=(25, 13))
ax = sns.barplot(x=playing_black.loc[playing_black['winner']=='black', :].opening_name.value_counts().values[0:20], 
                 y=playing_black.loc[playing_black['winner']=='black', :].opening_name.value_counts().index[0:20],
                 palette='mako')

# %% [markdown]
# ### ELO Curve

# %%
sorted_df = df.sort_values(by=['createdAt'])
sorted_df
# Out:
#       rated   variant      speed       perf                         createdAt  \
# 1259   True  standard  classical  classical  2019-04-09 12:29:18.450000+00:00
# 1258   True  standard      rapid      rapid  2019-04-12 02:55:21.683000+00:00
# 1257   True  standard      rapid      rapid  2019-04-13 20:43:08.889000+00:00
# 1256   True  standard      blitz      blitz  2019-04-13 20:54:06.845000+00:00
# 1255   True  standard      rapid      rapid  2019-04-15 22:12:18.221000+00:00
# ...     ...       ...        ...        ...                               ...
# 4      True  standard      blitz      blitz  2022-10-15 12:52:37.534000+00:00
# 3      True  standard      blitz      blitz  2022-10-16 16:21:10.320000+00:00
# 2      True  standard      blitz      blitz  2022-10-19 01:15:39.690000+00:00
# 1      True  standard      blitz      blitz  2022-10-19 01:20:20.352000+00:00
# 0      True  standard      blitz      blitz  2022-10-19 01:34:11.197000+00:00
#
#          status winner                                              moves  \
# 1259       draw    NaN  c4 e5 Nc3 Bc5 e3 Nf6 Nge2 Nc6 g3 b6 Bg2 Bb7 d4...
# 1258       mate  white  e4 c6 Bc4 d5 exd5 cxd5 Bb3 Bf5 d4 e6 h3 Nc6 c3...
# 1257       mate  white  e4 c6 d4 d5 e5 e6 Nf3 Ne7 Nc3 Nd7 Bd3 f6 O-O N...
# 1256     resign  black  c4 Nf6 Nc3 g6 g3 Bg7 Bg2 O-O e4 Re8 d3 d6 Nf3 ...
# 1255    timeout  white  e4 c5 Bc4 e6 e5 d5 Bb5+ Bd7 Bxd7+ Nxd7 c3 Nxe5...
# ...         ...    ...                                                ...
# 4          mate  white  e4 e5 Nf3 Nc6 Bb5 d6 c3 a6 Ba4 b5 Bc2 Bb7 O-O ...
# 3     outoftime  white  e4 d5 exd5 Qxd5 Nc3 Qd8 Nf3 Bg4 Be2 e6 d4 Bd6 ...
# 2          mate  white  d4 Nf6 Bg5 g6 Bxf6 exf6 e4 Bg7 Nf3 d5 e5 Nc6 B...
# 1        resign  white  e4 e5 Nf3 Nc6 Bb5 d6 c3 Be7 O-O Bg4 d3 Nf6 Re1...
# 0        resign  white  e4 d6 Nf3 g6 Bb5+ Bd7 Bxd7+ Nxd7 O-O Bg7 Nc3 c...
#
#                                                   clock  ECO  \
# 1259  {'initial': 900, 'increment': 15, 'totalTime':...  A21
# 1258  {'initial': 600, 'increment': 0, 'totalTime': ...  B10
# 1257  {'initial': 600, 'increment': 0, 'totalTime': ...  B12
# 1256  {'initial': 180, 'increment': 0, 'totalTime': ...  A16
# 1255  {'initial': 600, 'increment': 0, 'totalTime': ...  B20
# ...                                                 ...  ...
# 4     {'initial': 300, 'increment': 3, 'totalTime': ...  C74
# 3     {'initial': 300, 'increment': 3, 'totalTime': ...  B01
# 2     {'initial': 180, 'increment': 0, 'totalTime': ...  A45
# 1     {'initial': 180, 'increment': 2, 'totalTime': ...  C62
# 0     {'initial': 180, 'increment': 2, 'totalTime': ...  B00
#
#                                            opening_name   white_player rating  \
# 1259  English Opening: King's English Variation, Rev...   'chestroyer'   1500
# 1258                Caro-Kann Defense: Hillbilly Attack        'cyote'   1546
# 1257               Caro-Kann Defense: Advance Variation    'emerson88'   1386
# 1256  English Opening: Anglo-Indian Defense, Queen's...   'chestroyer'   1500
# 1255                   Sicilian Defense: Bowdler Attack  't-2wadbee-t'   1241
# ...                                                 ...            ...    ...
# 4     Ruy Lopez: Morphy Defense, Modern Steinitz Def...   'chestroyer'   1409
# 3         Scandinavian Defense: Mieses-Kotroc Variation   'chestroyer'   1415
# 2                                     Trompowsky Attack  'chinorafahh'   1410
# 1                           Ruy Lopez: Steinitz Defense   'chestroyer'   1414
# 0                                          Pirc Defense   'chestroyer'   1420
#
#       black_player rating.1     pawn_opening
# 1259    'mass1962'     1510  english opening
# 1258  'chestroyer'     1500        king pawn
# 1257  'chestroyer'     1346        king pawn
# 1256    'dancab07'     1506  english opening
# 1255  'chestroyer'     1241        king pawn
# ...            ...      ...              ...
# 4       'dddeusss'     1392        king pawn
# 3     'praulo1111'     1396        king pawn
# 2     'chestroyer'     1421       queen pawn
# 1       'albied17'     1386        king pawn
# 0         'huurti'     1379        king pawn
#
# [1260 rows x 16 columns]

# %%
sorted_df['moves'][1]
# Out:
# 'e4 e5 Nf3 Nc6 Bb5 d6 c3 Be7 O-O Bg4 d3 Nf6 Re1 O-O Nbd2 Re8 Nf1 a6 Ba4 b5 Bc2 b4 d4 exd4 cxd4 d5 e5 Nxd4 Qxd4 Bxf3 gxf3 Nh5 Ng3 c5 Qg4 Nxg3 fxg3 c4 Bh6 g6 f4 Bc5+ Kg2 a5 e6 f5 Bxf5 Qf6 Bc2 Qxb2 Rec1 Qd4 Bxg6 Qf2+ Kh3 Qd4 Bxe8+ Kh8 Rd1 Qf6 Bg5 Qg7 Rxd5 Rxe8 Rxc5 Qxa1 e7 Qg7 Rf5 Rxe7 Bf6 c3 Bxg7+ Rxg7 Rf8+'

# %%
rating = player_rating(player_name, df)
rating = pd.DataFrame(rating, columns=['createdAt', 'speed', 'rating'])
rating = rating.sort_values(['createdAt'])
rating['rating'] = clean_rating(rating)
rating
# Out:
#        createdAt      speed rating
# 1259  2019-04-09  classical   1500
# 1258  2019-04-12      rapid   1500
# 1256  2019-04-13      blitz   1500
# 1257  2019-04-13      rapid   1346
# 1255  2019-04-15      rapid   1241
# ...          ...        ...    ...
# 6     2022-10-15      blitz   1420
# 3     2022-10-16      blitz   1415
# 2     2022-10-19      blitz   1421
# 1     2022-10-19      blitz   1414
# 0     2022-10-19      blitz   1420
#
# [1260 rows x 3 columns]

# %%
rating['rating'] = rating['rating'].astype('int32')
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1260 entries, 1259 to 0
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   createdAt  1260 non-null   object
#  1   speed      1260 non-null   object
#  2   rating     1260 non-null   int32
# dtypes: int32(1), object(2)
# memory usage: 34.5+ KB

# %%
speed = [item for item in rating.speed.value_counts().index]
for item in speed[0:-1]:
    fig, ax = plt.subplots(figsize=(25, 10))
    ax = sns.lineplot(x=rating.loc[rating['speed']==item, :].createdAt, y=rating.loc[rating['speed']==item, :].rating)
    plt.title(f'{item} time')
    plt.ylim(800, 2000)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = sns.countplot(data=df, x='pawn_opening', palette='YlGnBu')
plt.title(f'Pawn Opening Barplot')
add_value_labels(ax)
