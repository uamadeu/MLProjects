# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
import yellowbrick

# %%
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %% [markdown]
# # Loading the datasets

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# # Treating data

# %% [markdown]
# ### Droping unnecessary columns

# %%
df_train.drop(['PassengerId', 'Name', 'Cabin', 'Ticket'], axis='columns', inplace=True)
df_test.drop(['PassengerId', 'Name', 'Cabin', 'Ticket'], axis='columns', inplace=True)

# %% [markdown]
# ### Getting Dummies

# %%
df_train = pd.get_dummies(df_train, columns=['Sex', 'Embarked'], drop_first=True)
df_test = pd.get_dummies(df_test, columns=['Sex', 'Embarked'], drop_first=True)
df_train
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0           0       3  22.0      1      0   7.2500         1           0
# 1           1       1  38.0      1      0  71.2833         0           0
# 2           1       3  26.0      0      0   7.9250         0           0
# 3           1       1  35.0      1      0  53.1000         0           0
# 4           0       3  35.0      0      0   8.0500         1           0
# ..        ...     ...   ...    ...    ...      ...       ...         ...
# 886         0       2  27.0      0      0  13.0000         1           0
# 887         1       1  19.0      0      0  30.0000         0           0
# 888         0       3   NaN      1      2  23.4500         0           0
# 889         1       1  26.0      0      0  30.0000         1           0
# 890         0       3  32.0      0      0   7.7500         1           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# ...

# %%
df_test
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  Embarked_S
# 0         3  34.5      0      0    7.8292         1           1           0
# 1         3  47.0      1      0    7.0000         0           0           1
# 2         2  62.0      0      0    9.6875         1           1           0
# 3         3  27.0      0      0    8.6625         1           0           1
# 4         3  22.0      1      1   12.2875         0           0           1
# ..      ...   ...    ...    ...       ...       ...         ...         ...
# 413       3   NaN      0      0    8.0500         1           0           1
# 414       1  39.0      0      0  108.9000         0           0           0
# 415       3  38.5      0      0    7.2500         1           0           1
# 416       3   NaN      0      0    8.0500         1           0           1
# 417       3   NaN      1      1   22.3583         1           0           0
#
# [418 rows x 8 columns]

# %%
df_train.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Age           177
# SibSp           0
# Parch           0
# Fare            0
# Sex_male        0
# Embarked_Q      0
# Embarked_S      0
# dtype: int64

# %%
df_train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#          Sex_male  Embarked_Q  Embarked_S
# count  891.000000  891.000000  891.000000
# mean     0.647587    0.086420    0.722783
# std      0.477990    0.281141    0.447876
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# ...

# %% [markdown]
# ### Correlation between variables

# %%
corr = df_train.corr()
matrix = np.triu(corr)
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='BrBG', mask=matrix)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='BrBG')
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
item = ['Age', 'Pclass', 'SibSp', 'Parch', 'Fare', 'Sex_male']
axes = axes.flatten()
for item, ax in zip(item, axes):
    sns.boxplot(data=df_train, x='Survived', y=item, ax=ax, palette='coolwarm')

# %%
fig, axes = plt.subplots(5, 1, figsize=(10, 30))
axes = axes.flatten()
item = ['Age', 'SibSp', 'Parch', 'Fare', 'Sex_male']
for item, ax in zip(item, axes):
    sns.barplot(data=df_train, x='Survived', y=item, ax=ax, palette='coolwarm', hue='Pclass')

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax = plt.hist(df_train['Age'], bins=25)

# %%
plt.figure(figsize=(10, 10))
sns.histplot(data=df_train, x='Age', hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(10, 10))
sns.histplot(data=df_train, x='Age', hue='Survived', palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### Imputing missing data

# %%
imputer = SimpleImputer(strategy='median')
imputed_train = imputer.fit_transform(df_train)
imputed_test = imputer.fit_transform(df_test)

# %%
sca = StandardScaler()
lenc = LabelEncoder()
X_train = sca.fit_transform(imputed_train)
X_train = pd.DataFrame(X_train)
X_test = sca.fit_transform(imputed_test)
X_test = pd.DataFrame(X_test)

# %%
Y_train = X_train[0]
X_train.drop([0], axis='columns', inplace=True)
X_train
# Out:
#             1         2         3         4         5         6         7  \
# 0    0.827377 -0.565736  0.432793 -0.473674 -0.502445  0.737695 -0.307562
# 1   -1.566107  0.663861  0.432793 -0.473674  0.786845 -1.355574 -0.307562
# 2    0.827377 -0.258337 -0.474545 -0.473674 -0.488854 -1.355574 -0.307562
# 3   -1.566107  0.433312  0.432793 -0.473674  0.420730 -1.355574 -0.307562
# 4    0.827377  0.433312 -0.474545 -0.473674 -0.486337  0.737695 -0.307562
# ..        ...       ...       ...       ...       ...       ...       ...
# 886 -0.369365 -0.181487 -0.474545 -0.473674 -0.386671  0.737695 -0.307562
# 887 -1.566107 -0.796286 -0.474545 -0.473674 -0.044381 -1.355574 -0.307562
# 888  0.827377 -0.104637  0.432793  2.008933 -0.176263 -1.355574 -0.307562
# 889 -1.566107 -0.258337 -0.474545 -0.473674 -0.044381  0.737695 -0.307562
# 890  0.827377  0.202762 -0.474545 -0.473674 -0.492378  0.737695  3.251373
#
#             8
# 0    0.619306
# 1   -1.614710
# 2    0.619306
# 3    0.619306
# ...

# %% [markdown]
# ### Label Encoding Y_train

# %%
Y_train = lenc.fit_transform(Y_train)

# %% [markdown]
# ### Loading the models e calculating AUC

# %%
predictions = {}
for model in [LogisticRegression(), 
              DecisionTreeClassifier(), 
              KNeighborsClassifier(), 
              GaussianNB(), 
              SVC(probability=True), 
              RandomForestClassifier()
             ]:
    
    cls = model
    cls.fit(X_train, Y_train)
    pred = cls.predict(X_test)
    predictions[cls] = pred
    kfold = model_selection.KFold(n_splits=10)
    s = model_selection.cross_val_score(cls, X_train, Y_train, scoring='roc_auc', cv=kfold)
        
    print(f"{model} AUC:"
          f"{s.mean():.3f} STD: {s.std():.2f}")
    
    roc = yellowbrick.ROCAUC(cls)
    roc.fit(X_train, Y_train)
    roc.score(X_train, Y_train)
    roc.show()
# Out:
# LogisticRegression() AUC:0.848 STD: 0.03
# DecisionTreeClassifier() AUC:0.780 STD: 0.05
# KNeighborsClassifier() AUC:0.843 STD: 0.04
# GaussianNB() AUC:0.825 STD: 0.03
# SVC(probability=True) AUC:0.858 STD: 0.04
# RandomForestClassifier() AUC:0.858 STD: 0.04

# %%
predict = pd.DataFrame(data={list(predictions.keys())[0]:list(predictions.values())[0], 
                             'DecisionTreeClassifier()':list(predictions.values())[1],
                             list(predictions.keys())[2]:list(predictions.values())[2],
                             list(predictions.keys())[3]:list(predictions.values())[3],
                             list(predictions.keys())[4]:list(predictions.values())[4],
                             'RandomForestClassifier()':list(predictions.values())[5]
                            })

# %%
predict
# Out:
#      LogisticRegression()  DecisionTreeClassifier()  KNeighborsClassifier()  \
# 0                       0                         0                       0
# 1                       0                         0                       0
# 2                       0                         1                       0
# 3                       0                         0                       1
# 4                       1                         1                       0
# ..                    ...                       ...                     ...
# 413                     0                         1                       1
# 414                     1                         1                       1
# 415                     0                         0                       0
# 416                     0                         1                       1
# 417                     0                         1                       1
#
# ...

# %%
predict.describe()
# Out:
#        LogisticRegression()  DecisionTreeClassifier()  KNeighborsClassifier()  \
# count            418.000000                418.000000              418.000000
# mean               0.356459                  0.382775                0.435407
# std                0.479527                  0.486647                0.496404
# min                0.000000                  0.000000                0.000000
# 25%                0.000000                  0.000000                0.000000
# 50%                0.000000                  0.000000                0.000000
# 75%                1.000000                  1.000000                1.000000
# max                1.000000                  1.000000                1.000000
#
#        GaussianNB()  SVC(probability=True)  RandomForestClassifier()
# count    418.000000             418.000000                418.000000
# mean       0.394737               0.303828                  0.325359
# ...

# %% [markdown]
# ### Survivability according to each model

# %%
for column in [x for x in predict.columns]:
    print(f'Model: {column}, Survivors percentual: {round(predict[column].mean()*100, 4)} %')
# Out:
# Model: LogisticRegression(), Survivors percentual: 35.6459 %
# Model: DecisionTreeClassifier(), Survivors percentual: 38.2775 %
# Model: KNeighborsClassifier(), Survivors percentual: 43.5407 %
# Model: GaussianNB(), Survivors percentual: 39.4737 %
# Model: SVC(probability=True), Survivors percentual: 30.3828 %
# Model: RandomForestClassifier(), Survivors percentual: 32.5359 %
