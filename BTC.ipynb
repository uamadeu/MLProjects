# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df= yf.download(tickers = 'BTC-USD', period = '6y', interval='1d')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2016-06-04    569.705017    590.132019    564.237976    572.726990
# 2016-06-05    573.307983    582.807983    569.177979    574.976990
# 2016-06-06    574.601990    586.469971    574.601990    585.536987
# 2016-06-07    585.445007    590.258972    567.513977    576.596985
# 2016-06-08    577.166992    582.838989    573.130005    581.645020
# ...                  ...           ...           ...           ...
# 2022-05-31  31723.865234  32249.863281  31286.154297  31792.310547
# 2022-06-01  31792.554688  31957.285156  29501.587891  29799.080078
# 2022-06-02  29794.890625  30604.734375  29652.705078  30467.488281
# 2022-06-03  30467.806641  30633.035156  29375.689453  29704.390625
# 2022-06-04  29693.560547  29740.394531  29507.761719  29585.775391
#
#                Adj Close       Volume
# Date
# 2016-06-04    572.726990     94925296
# ...

# %%
variation = []
percentual_variation = []
for index in range(len(df.Open)):
    variation.append(round(df.Close[index] - df.Open[index], 2))
    percentual_variation.append(round((df.Close[index] - df.Open[index])/df.Open[index], 2))
df['Variation'] = variation
df['Percentual Variation'] = percentual_variation

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   2192.000000   2192.000000   2192.000000   2192.000000   2192.000000
# mean   15733.659691  16145.485926  15276.264316  15744.758767  15744.758767
# std    17406.518832  17856.193668  16884.738202  17401.791395  17401.791395
# min      548.656006    573.359985    531.333984    547.465027    547.465027
# 25%     3999.921692   4081.469543   3904.959167   4004.579956   4004.579956
# 50%     8376.559082   8620.701172   8184.578125   8399.778809   8399.778809
# 75%    18881.176758  19353.953613  18349.764160  19109.148438  19109.148438
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125
#
#              Volume    Variation  Percentual Variation
# count  2.192000e+03  2192.000000           2192.000000
# mean   1.961370e+10    11.099056              0.002473
# std    2.063782e+10   912.526599              0.040217
# min    3.397780e+07 -7564.000000             -0.370000
# ...

# %%
plt.figure(figsize=(30, 30))
sns.scatterplot(x=df.index, y=df.Open, hue=None)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
plt.figure(figsize=(30, 30))
sns.scatterplot(x=df.index, y=df.Close)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
plt.figure(figsize=(30,30))
sns.scatterplot(x=df.index, y=df['Variation'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Variation'>
